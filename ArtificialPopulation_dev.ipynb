# %%
import numpy as np
import pandas as pd
from typing import Dict, List, Tuple, Optional
import random
from numpy.random.mtrand import randint
import csv
from pathlib import Path
import json

# %%
rng = np.random.default_rng(seed=42)

# %% [markdown]
# ##Core demographic profiles
#  Core demographic profiles defining statistical parameters for 9 socioeconomic groups
#  Each profile includes means/standard deviations for key attributes and probability distributions
#  Note: race_dist uses cumulative probabilities [White, Black, Asian, Other] for UK demographics

# %%
demographic_profiles = {
    'affluent_professional': {
        'age_mean': 42, 'age_std': 9,
        'education_mean': 6.5, 'education_std': 1.2,
        'income_mean': 65000, 'income_std': 20000,
        'race_dist': [0.85, 0.05, 0.08, 0.02],
        'family_ratio': 0.6,
        'urban_preference': 0.8,
        'rural_preference': 0.2,
        'household_type_probabilities': {
            'single_person': 0.15,       # Often live alone in city apartments
            'couple_no_children': 0.45,  # Very high - DINK lifestyle
            'nuclear_family': 0.30,      # Professional families
            'single_parent_family': 0.03, # Rare
            'shared_household': 0.02,    # Very rare
            'multi_generational': 0.05   # Some cultural variation
        },
        'typical_children': [0, 1, 2],    # If they have children
        'children_probabilities': [0.4, 0.4, 0.2],  # 0, 1, or 2 children
        'notes': 'High dual-income couples, late childbearing'
    },

    'middle_class': {
        'age_mean': 45, 'age_std': 10,
        'education_mean': 4.5, 'education_std': 1.5,
        'income_mean': 38000, 'income_std': 12000,
        'race_dist': [0.88, 0.04, 0.06, 0.02],
        'family_ratio': 0.7,
        'urban_preference': 0.6,
        'rural_preference': 0.4,
        'household_type_probabilities': {
            'single_person': 0.20,
            'couple_no_children': 0.30,   # Strong couple presence
            'nuclear_family': 0.35,       # Classic family unit
            'single_parent_family': 0.08,
            'shared_household': 0.04,
            'multi_generational': 0.03
        },
        'typical_children': [0, 1, 2, 3],
        'children_probabilities': [0.3, 0.4, 0.25, 0.05],
        'notes': 'Traditional family structures, suburban living'
    },

    'working_class': {
        'age_mean': 48, 'age_std': 11,
        'education_mean': 2.5, 'education_std': 1.2,
        'income_mean': 26000, 'income_std': 8000,
        'race_dist': [0.90, 0.03, 0.05, 0.02],
        'family_ratio': 0.65,
        'urban_preference': 0.4,
        'rural_preference': 0.6,
        'household_type_probabilities': {
            'single_person': 0.25,        # Often elderly or divorced
            'couple_no_children': 0.25,   # Traditional couples
            'nuclear_family': 0.30,       # Working-class families
            'single_parent_family': 0.15, # Higher than average
            'shared_household': 0.03,
            'multi_generational': 0.02
        },
        'typical_children': [1, 2, 3],
        'children_probabilities': [0.4, 0.4, 0.2],
        'notes': 'Earlier childbearing, larger families traditionally'
    },

    'student': {
        'age_mean': 22, 'age_std': 4,
        'education_mean': 5.5, 'education_std': 1.5,
        'income_mean': 12000, 'income_std': 8000,
        'race_dist': [0.75, 0.06, 0.15, 0.04],
        'family_ratio': 0.05,
        'urban_preference': 0.9,
        'rural_preference': 0.1,
        'household_type_probabilities': {
            'single_person': 0.10,        # In university accommodation
            'couple_no_children': 0.05,   # Student couples rare
            'nuclear_family': 0.01,       # Very rare (mature students)
            'single_parent_family': 0.01, # Very rare
            'shared_household': 0.80,     # VERY high - student houses
            'multi_generational': 0.03    # Living with parents
        },
        'typical_children': [0],          # Virtually no children
        'children_probabilities': [1.0],
        'notes': 'Mostly in shared housing, some in halls, few with families'
    },

    'retired': {
        'age_mean': 72, 'age_std': 8,
        'education_mean': 2.8, 'education_std': 1.5,
        'income_mean': 22000, 'income_std': 10000,
        'race_dist': [0.95, 0.02, 0.02, 0.01],
        'family_ratio': 0.3,
        'urban_preference': 0.3,
        'rural_preference': 0.7,
        'household_type_probabilities': {
            'single_person': 0.40,        # Very high - widows/widowers
            'couple_no_children': 0.45,   # Retired couples
            'nuclear_family': 0.02,       # Living with adult children
            'single_parent_family': 0.01,
            'shared_household': 0.01,     # Very rare
            'multi_generational': 0.11    # Living with family
        },
        'typical_children': [0],          # Children grown and left
        'children_probabilities': [1.0],
        'notes': 'High proportion living alone, many in care homes (not captured)'
    },

    'low_income': {
        'age_mean': 38, 'age_std': 12,
        'education_mean': 1.2, 'education_std': 1.0,
        'income_mean': 16000, 'income_std': 6000,
        'race_dist': [0.82, 0.08, 0.07, 0.03],
        'family_ratio': 0.5,
        'urban_preference': 0.7,
        'rural_preference': 0.3,
        'household_type_probabilities': {
            'single_person': 0.30,        # Often single in social housing
            'couple_no_children': 0.15,   # Less stable relationships
            'nuclear_family': 0.20,       # Families in poverty
            'single_parent_family': 0.25, # Very high
            'shared_household': 0.08,     # House sharing due to costs
            'multi_generational': 0.02
        },
        'typical_children': [1, 2, 3],
        'children_probabilities': [0.5, 0.3, 0.2],
        'notes': 'High single parenthood, housing insecurity'
    },

    'young_professional': {
        'age_mean': 28, 'age_std': 4,
        'education_mean': 6.0, 'education_std': 1.0,
        'income_mean': 32000, 'income_std': 10000,
        'race_dist': [0.80, 0.05, 0.12, 0.03],
        'family_ratio': 0.2,
        'urban_preference': 0.9,
        'rural_preference': 0.1,
        'household_type_probabilities': {
            'single_person': 0.35,        # City living
            'couple_no_children': 0.40,   # Dual-income couples
            'nuclear_family': 0.10,       # Early starters
            'single_parent_family': 0.02,
            'shared_household': 0.12,     # Flat shares in expensive cities
            'multi_generational': 0.01
        },
        'typical_children': [0, 1],       # Mostly no children
        'children_probabilities': [0.9, 0.1],
        'notes': 'Delayed childbearing, urban concentration'
    },

    'farmer_agricultural': {
        'age_mean': 52, 'age_std': 12,
        'education_mean': 2.0, 'education_std': 1.0,
        'income_mean': 28000, 'income_std': 15000,
        'race_dist': [0.98, 0.01, 0.005, 0.005],
        'family_ratio': 0.75,
        'urban_preference': 0.1,
        'rural_preference': 0.9,
        'household_type_probabilities': {
            'single_person': 0.15,        # Elderly farmers
            'couple_no_children': 0.25,   # Farming couples
            'nuclear_family': 0.40,       # Farm families
            'single_parent_family': 0.05,
            'shared_household': 0.02,     # Farm workers sometimes
            'multi_generational': 0.13    # Farm succession important
        },
        'typical_children': [1, 2, 3, 4], # Larger families traditionally
        'children_probabilities': [0.3, 0.4, 0.2, 0.1],
        'notes': 'Strong family farms, multi-generational working'
    },

    'rural_worker': {
        'age_mean': 46, 'age_std': 11,
        'education_mean': 1.8, 'education_std': 0.8,
        'income_mean': 22000, 'income_std': 7000,
        'race_dist': [0.96, 0.02, 0.01, 0.01],
        'family_ratio': 0.7,
        'urban_preference': 0.2,
        'rural_preference': 0.8,
        'household_type_probabilities': {
            'single_person': 0.20,
            'couple_no_children': 0.30,
            'nuclear_family': 0.35,       # Rural families
            'single_parent_family': 0.08,
            'shared_household': 0.04,     # Sometimes seasonal workers
            'multi_generational': 0.03
        },
        'typical_children': [1, 2, 3],
        'children_probabilities': [0.4, 0.4, 0.2],
        'notes': 'Similar to working class but more rural'
    }
}

# %% [markdown]
# ##Geographic area
# Geographic area type definitions showing demographic composition percentages. Each area type has a distinct socioeconomic mix — for example, university towns have high student concentrations (35%), while coastal areas are retirement-heavy (50% retired). Values represent proportional distributions that sum to approximately 1.0 within each area.

# %%
area_types = {
    'city': {  # Bristol, Leeds, Edinburgh, Cardiff
        'demographic_distribution': {
            'affluent_professional': 0.15,
            'young_professional': 0.15,
            'middle_class': 0.25,
            'student': 0.10,
            'working_class': 0.20,
            'low_income': 0.10,
            'retired': 0.05
        },
        'household_type_distribution': {
            'single_person': 0.30,
            'couple_no_children': 0.28,   # Strong couple presence
            'nuclear_family': 0.22,       # More families than major cities
            'single_parent_family': 0.08,
            'shared_household': 0.09,
            'multi_generational': 0.03
        },
        'urban': True,
        'population_density': 'high',
        'typical_household_size': 2.3
    },
    'agricultural': {  # East Anglia, Lincolnshire, parts of Yorkshire
        'demographic_distribution': {
            'farmer_agricultural': 0.25,
            'rural_worker': 0.20,
            'working_class': 0.20,
            'retired': 0.20,
            'middle_class': 0.10,
            'affluent_professional': 0.05
        },
        'household_type_distribution': {
            'single_person': 0.22,        # Elderly farmers, widows/widowers
            'couple_no_children': 0.20,   # Farming couples
            'nuclear_family': 0.35,       # STRONG - farm families with children
            'single_parent_family': 0.05, # Lower than urban
            'shared_household': 0.03,     # Very rare
            'multi_generational': 0.15    # HIGH - farm succession, elderly parents
        },
        'urban': False,
        'population_density': 'very_low',
        'typical_household_size': 3.1,    # Larger rural families
        'notes': 'Farm families often multi-generational'
    },
    'market_town': {  # Traditional rural hubs
        'demographic_distribution': {
            'middle_class': 0.30,
            'working_class': 0.25,
            'retired': 0.20,
            'rural_worker': 0.15,
            'affluent_professional': 0.10
        },
        'household_type_distribution': {
            'single_person': 0.25,
            'couple_no_children': 0.30,   # Strong - commuter couples
            'nuclear_family': 0.25,       # Good for families
            'single_parent_family': 0.08,
            'shared_household': 0.07,     # Some young workers
            'multi_generational': 0.05
        },
        'urban': False,
        'population_density': 'low_medium',
        'typical_household_size': 2.5,
        'commuter_patterns': 'Many commute to nearby cities'
    },
}

# %% [markdown]
# ## Household Structure Definitions
#
# Household structure type definitions showing composition patterns and size distributions. Each structure type represents a distinct living arrangement pattern — for example, single-parent households typically have 1-2 children (70% have 1 child), while multi-adult shared households often consist of 2-4 unrelated adults. Size distributions represent proportional likelihoods of different household sizes within each structure type, with values summing to 1.0 within each structure.

# %%
household_types = {
    # Key: (adults, children) where children = dependent children (<18)
    # Value: Probability distribution of household sizes within this structure

    # Single adult, no children
    'single_person': {
        'description': 'One adult living alone',
        'size_distribution': {
            1: 1.0  # Always exactly 1 person
        }
    },

    # Couple, no children
    'couple_no_children': {
        'description': 'Two adults in a relationship, no dependent children',
        'size_distribution': {
            2: 1.0  # Always exactly 2 people
        }
    },

    # Couple with children
    'nuclear_family': {
        'description': 'Two adults with 1+ dependent children',
        'size_distribution': {
            3: 0.40,  # 40% have 1 child
            4: 0.45,  # 45% have 2 children
            5: 0.12,  # 12% have 3 children
            6: 0.03   # 3% have 4+ children
        }
    },

    # Single parent with children
    'single_parent_family': {
        'description': 'One adult with 1+ dependent children',
        'size_distribution': {
            2: 0.70,  # 70% have 1 child
            3: 0.25,  # 25% have 2 children
            4: 0.05   # 5% have 3+ children
        }
    },

    # Multiple adults, no children (shared household)
    'shared_household': {
        'description': 'Multiple unrelated adults sharing accommodation',
        'size_distribution': {
            2: 0.40,  # 40% are 2 people
            3: 0.35,  # 35% are 3 people
            4: 0.20,  # 20% are 4 people
            5: 0.05   # 5% are 5+ people
        }
    },

    # Complex/multi-generational
    'multi_generational': {
        'description': 'Multiple generations or complex family structures',
        'size_distribution': {
            3: 0.30,  # 30% are 3 people
            4: 0.40,  # 40% are 4 people
            5: 0.20,  # 20% are 5 people
            6: 0.10   # 10% are 6+ people
        }
    }
}

# %% [markdown]
# ##Core population generation
# Core population generation function using "roulette wheel" selection. Creates individuals with demographic attributes drawn from statistical distributions. Implements proportional sampling to match area composition, generates unique IDs, and produces complete individual records ready for household formation. Returns list of person dictionaries with attributes like age, income, education, ethnicity, and family indicators.

# %%
def generate_individuals_wheel(area, area_id, population):
    """
    Generate synthetic individuals for a specific area using proportional selection.

    This function creates a population of individuals where:
    - Each individual belongs to a demographic profile (affluent, middle_class, etc.)
    - The proportion of each profile matches the area's composition
    - Individual attributes are drawn from normal distributions based on their profile

    Parameters:
    -----------
    area : dict
        Dictionary defining the demographic composition of the area
        Format: {'affluent': 0.3, 'middle_class': 0.4, 'working_class': 0.3}
        Keys are demographic profile names, values are proportions (should sum to ~1.0)

    area_id : str
        Unique identifier for this area (e.g., 'LON_01', 'MAN_02')
        Used to create unique individual IDs

    population : int
        Number of individuals to generate for this area

    Returns:
    --------
    list: List of individual dictionaries with demographic attributes
    """


    
    for i in range(population):
        wheel =[]
        keys = []
        count =0
        demographic = area["demographic_distribution"]
        for key,value in demographic.items():
            count+=value
            wheel.append(count)
            keys.append(key)

        indx=0    
        rnd_demographic= random.random*max(wheel)
        while rnd_demographic > wheel[indx]:
            count += 1

        # Step 2c: Get the selected demographic profile
        demographic_id = keys[indx]  # Profile name (e.g., 'middle_class')
        demographic = demographic_profiles[demographic_id]  # Full profile dictionary

        # Step 2d: Generate age from normal distribution
        # Clamp to reasonable bounds (implied - could add explicit bounds)
        age = int(rng.normal(
            loc=demographic["age_mean"],       # Center of distribution
            scale=demographic["age_std"],      # Spread of distribution
            size=1                             # Generate 1 value
        )[0])

        # Step 2e: Generate education level from normal distribution
        # UK system: 0-8 levels
        education = int(rng.normal(
            loc=demographic["education_mean"],
            scale=demographic["education_std"],
            size=1
        )[0])

        # Step 2f: Assign gender (0 or 1, typically 0=male, 1=female)
        # Equal probability for each gender (0.5 each)
        gender = random.randint(0, 1)

        # Step 2g: Assign ethnicity using another roulette wheel
        # race_dist is cumulative probabilities for ethnicities
        # Example: [0.7, 0.85, 0.95, 1.0] means:
        #   White: 70%, Black: 15%, Asian: 10%, Other: 5%
        wheel =[]
        keys = []
        count =0
        ethnic_dict = demographic["race_dist"]
        for key,value in ethnic_dict.items():
            count+=value
            wheel.append(count)
            keys.append(key)

        rnd_race = random.random() * max(wheel)  # Scale to last cumulative value

        # Find which ethnicity corresponds to the random number
        indx = 0
        while race_rnd > wheel[indx]:
            indx += 1
        ethnicity = indx  # 0=White, 1=Black, 2=Asian, 3=Other

        # Step 2h: Get family ratio (probability of being in a couple/family)
        family_ratio = demographic["family_ratio"]

        # Step 2i: Generate income from normal distribution (£)
        income = int(rng.normal(
            loc=demographic["income_mean"],
            scale=demographic["income_std"],
            size=1
        )[0])

        # Step 2j: Create individual dictionary with all attributes
        individual = {
            "id": str(area_id) + "_" + str(i),          # Unique ID: "LON_01_0", "LON_01_1", etc.
            "demographic_id": demographic_id,           # Profile type
            "age": age,                                 # Integer age
            "education": education,                     # Education level (0-8)
            "gender": gender,                           # 0 or 1
            "ethnicity": ethnicity,                     # 0, 1, 2, or 3
            "family_ratio": family_ratio,               # Probability of being in couple
            "income": income,                           # Annual income in £
            "in_household": False,                      # Tracking for household formation
            "household_id": "",                         # Will be filled during household creation
            "relationship": ""                          # Will be "head", "partner", etc.
        }

        # Add individual to this area's population
        local_population.append(individual)

    # Step 3: Return complete population for this area
    return local_population

# %%
def generate_individuals(area, area_id, population):
    """
    Generate synthetic individuals for a specific area using proportional selection.

    This function creates a population of individuals where:
    - Each individual belongs to a demographic profile (affluent, middle_class, etc.)
    - The proportion of each profile matches the area's composition
    - Individual attributes are drawn from normal distributions based on their profile

    Parameters:
    -----------
    area : dict
        Dictionary defining the demographic composition of the area
        Format: {'affluent': 0.3, 'middle_class': 0.4, 'working_class': 0.3}
        Keys are demographic profile names, values are proportions (should sum to ~1.0)

    area_id : str
        Unique identifier for this area (e.g., 'LON_01', 'MAN_02')
        Used to create unique individual IDs

    population : int
        Number of individuals to generate for this area

    Returns:
    --------
    list: List of individual dictionaries with demographic attributes
    """

    # Step 1: Create a "roulette wheel" for proportional selection
    # This allows us to randomly select demographic profiles according to area proportions
    wheel = []        # Cumulative probability wheel
    local_population = []  # List to store generated individuals
    summation = 0     # Running total of probabilities (should end at ~1.0)

    # Build the cumulative probability wheel
    for key, value in area["demographic_distribution"].items():
        # Add current profile's proportion to running total
        summation += value

        # Store cumulative probability and profile name
        # Example: If area = {'affluent': 0.3, 'middle_class': 0.4, 'working_class': 0.3}
        # wheel becomes: [[0.3, 'affluent'], [0.7, 'middle_class'], [1.0, 'working_class']]
        wheel.append([summation, key])

    # Step 2: Generate the specified number of individuals
    for i in range(population):
        # Step 2a: Spin the roulette wheel - pick a random number 0 to total probability
        rnd = random.random() * summation

        # Step 2b: Find which profile this random number corresponds to
        count = 0
        # Linear search through cumulative probabilities
        # Example: rnd = 0.5, wheel = [[0.3, 'affluent'], [0.7, 'middle_class'], [1.0, 'working_class']]
        # 0.5 > 0.3? Yes → count=1
        # 0.5 > 0.7? No → stop, demographic_id = 'middle_class'
        while rnd > wheel[count][0]:
            count += 1

        # Step 2c: Get the selected demographic profile
        demographic_id = wheel[count][1]  # Profile name (e.g., 'middle_class')
        demographic = demographic_profiles[demographic_id]  # Full profile dictionary

        # Step 2d: Generate age from normal distribution
        # Clamp to reasonable bounds (implied - could add explicit bounds)
        age = int(rng.normal(
            loc=demographic["age_mean"],       # Center of distribution
            scale=demographic["age_std"],      # Spread of distribution
            size=1                             # Generate 1 value
        )[0])

        # Step 2e: Generate education level from normal distribution
        # UK system: 0-8 levels
        education = int(rng.normal(
            loc=demographic["education_mean"],
            scale=demographic["education_std"],
            size=1
        )[0])

        # Step 2f: Assign gender (0 or 1, typically 0=male, 1=female)
        # Equal probability for each gender (0.5 each)
        gender = random.randint(0, 1)

        # Step 2g: Assign ethnicity using another roulette wheel
        # race_dist is cumulative probabilities for ethnicities
        # Example: [0.7, 0.85, 0.95, 1.0] means:
        #   White: 70%, Black: 15%, Asian: 10%, Other: 5%
        race_rnd = random.random() * demographic["race_dist"][-1]  # Scale to last cumulative value

        # Find which ethnicity corresponds to the random number
        count = 0
        while race_rnd > demographic["race_dist"][count]:
            count += 1
        ethnicity = count  # 0=White, 1=Black, 2=Asian, 3=Other

        # Step 2h: Get family ratio (probability of being in a couple/family)
        family_ratio = demographic["family_ratio"]

        # Step 2i: Generate income from normal distribution (£)
        income = int(rng.normal(
            loc=demographic["income_mean"],
            scale=demographic["income_std"],
            size=1
        )[0])

        # Step 2j: Create individual dictionary with all attributes
        individual = {
            "id": str(area_id) + "_" + str(i),          # Unique ID: "LON_01_0", "LON_01_1", etc.
            "demographic_id": demographic_id,           # Profile type
            "age": age,                                 # Integer age
            "education": education,                     # Education level (0-8)
            "gender": gender,                           # 0 or 1
            "ethnicity": ethnicity,                     # 0, 1, 2, or 3
            "family_ratio": family_ratio,               # Probability of being in couple
            "income": income,                           # Annual income in £
            "in_household": False,                      # Tracking for household formation
            "household_id": "",                         # Will be filled during household creation
            "relationship": ""                          # Will be "head", "partner", etc.
        }

        # Add individual to this area's population
        local_population.append(individual)

    # Step 3: Return complete population for this area
    return local_population

# %% [markdown]
# ##Probability Combination Function
#
# The combine_probabilities() function implements a simple Bayesian approach to household type determination by multiplying individual and area probabilities. This method follows the logical principle that a household type should be considered likely only if it's plausible both for the individual's demographic profile and for the geographic area type. After multiplication, probabilities are renormalized to ensure they sum to 1.0, creating a valid probability distribution ready for weighted random selection via roulette wheel sampling. The fallback to equal probability distribution ensures robustness when all combined probabilities evaluate to zero.

# %%
def combine_probabilities(person_probs, area_probs):
    """
    EVEN SIMPLER: Just multiply
    """
    combined = {}

    for hh_type in set(person_probs.keys()) | set(area_probs.keys()):
        p = person_probs.get(hh_type, 0)
        a = area_probs.get(hh_type, 0)
        combined[hh_type] = p * a

    # Renormalize
    total = sum(combined.values())
    if total > 0:
        combined = {k: v/total for k, v in combined.items()}
    else:
        # Fallback to equal probability
        combined = {k: 1/len(combined) for k in combined.keys()}
    hh_type =[]
    wheel=[]
    count=0
    for key, value in combined.items():
        hh_type.append(key)
        count+=value
        wheel.append(count)

    return hh_type,wheel

# %% [markdown]
# ##Relationship compatibility
# Relationship compatibility scoring algorithm. Computes similarity between two individuals based on multiple weighted factors: age, education, income (log-scaled), ethnicity, and demographic profile. Includes hard filters for gender preference (90% heterosexual assumption) and family willingness. Returns 0-1 score where higher values indicate better match potential for household formation.

# %%
def calculate_similarity_score_non_gender(person1, person2):

    # 1. Age similarity: Closer age = higher score
    age_diff = abs(person1['age'] - person2['age'])
    age_similarity = 1 / (1 + age_diff / 5)  # Normalized, 5-year difference = 0.5

    # 2. Education similarity: Similar education level = higher score
    edu_diff = abs(person1['education'] - person2['education'])
    edu_similarity = 1 / (1 + edu_diff / 2)  # Normalized, 2-level difference = 0.5

    # 3. Income similarity (log scale, as income differences matter less at high incomes)
    income1 = max(person1['income'], 10000)  # Avoid log(0)
    income2 = max(person2['income'], 10000)
    income_ratio = max(income1, income2) / min(income1, income2)
    income_similarity = 1 / (1 + np.log(income_ratio))  # Log scale normalization

    # 4. Ethnicity similarity: Same ethnicity
    ethnicity_similarity = 1.0 if person1['ethnicity'] == person2['ethnicity'] else 0.3

    # 5. Profile similarity: Same demographic profile = bonus
    same_profile = person1['demographic_id'] == person2['demographic_id']

    # Combine all components with weights
    weights = {
        'age': 0.25,        # Age is important but not everything
        'education': 0.20,  # Education level matters for compatibility
        'income': 0.20,     # Similar socioeconomic status
        'ethnicity': 0.15,  # Ethnic homophily (people tend to partner within ethnicity)
        'profile': 0.20     # Overall demographic profile similarity
    }

    # Calculate weighted sum
    score = (
        weights['age'] * age_similarity +
        weights['education'] * edu_similarity +
        weights['income'] * income_similarity +
        weights['ethnicity'] * ethnicity_similarity
    )
    return score

# %% [markdown]
# ##Couple Compatibility
#
# The calculate_similarity_score() function implements a partner compatibility algorithm that evaluates potential romantic/cohabiting partnerships between two adult individuals. It combines demographic similarity assessment with realistic social constraints to determine relationship viability.

# %%
def calculate_similarity_score(person1, person2):
    if person1['gender'] == person2['gender'] and random.random() > 0.9:  # 90% heterosexual
        return 0.0

    # 1. Age similarity: Closer age = higher score
    age_diff = abs(person1['age'] - person2['age'])
    age_similarity = 1 / (1 + age_diff / 5)  # Normalized, 5-year difference = 0.5

    # 2. Education similarity: Similar education level = higher score
    edu_diff = abs(person1['education'] - person2['education'])
    edu_similarity = 1 / (1 + edu_diff / 2)  # Normalized, 2-level difference = 0.5

    # 3. Income similarity (log scale, as income differences matter less at high incomes)
    income1 = max(person1['income'], 10000)  # Avoid log(0)
    income2 = max(person2['income'], 10000)
    income_ratio = max(income1, income2) / min(income1, income2)
    income_similarity = 1 / (1 + np.log(income_ratio))  # Log scale normalization

    # 4. Ethnicity similarity: Same ethnicity
    ethnicity_similarity = 1.0 if person1['ethnicity'] == person2['ethnicity'] else 0.3

    # 5. Profile similarity: Same demographic profile = bonus
    same_profile = person1['demographic_id'] == person2['demographic_id']

    # Combine all components with weights
    weights = {
        'age': 0.25,        # Age is important but not everything
        'education': 0.20,  # Education level matters for compatibility
        'income': 0.20,     # Similar socioeconomic status
        'ethnicity': 0.15,  # Ethnic homophily (people tend to partner within ethnicity)
        'profile': 0.20     # Overall demographic profile similarity
    }

    # Calculate weighted sum
    score = (
        weights['age'] * age_similarity +
        weights['education'] * edu_similarity +
        weights['income'] * income_similarity +
        weights['ethnicity'] * ethnicity_similarity
    )
    return score

# %% [markdown]
# ##Multi Generational
# The multi_generational() function implements compatibility algorithm that evaluates potential romantic/cohabiting partnerships between two adult individuals and then adds additional older houshold members. It combines demographic similarity assessment with realistic social constraints to determine relationship viability.

# %%
def multi_generational(pop,processed,household,hh_size,person1,hh_id):
    potential = []
    for p in pop:
        # Compute similarity (e.g., age, interests, socioeconomic status).
        similarity = calculate_similarity_score(person1, p)
        # Only keep candidates that are sufficiently similar.
        if similarity > 0.3:
            potential.append(p)

    # If we found at least one candidate, pick one at random.
    if potential:
        person2 = random.choice(potential)
        # Remove the chosen partner from the pool and record them.
        if person2 in pop:
            pop.remove(person2)
            processed.append(person2)

            # Update partner metadata.
            person2["in_household"] = True
            person2["relationship"] = "partner"
            person2["household_id"] = hh_id

            # Add the partner to the household’s member list.
            household["members"].append(person2)

    potential = []
    for p in pop:
        # Only keep candidates that of correct age.
        if p["age"]>person1["age"]+16:
            potential.append(p)
    if hh_size>2:
        hh_size=hh_size-2
        for i in range(hh_size):
            if potential:
                person2 = random.choice(potential)
                # Remove the chosen partner from the pool and record them.
                if person2 in pop:
                    pop.remove(person2)
                    processed.append(person2)

                    # Update partner metadata.
                    person2["in_household"] = True
                    person2["relationship"] = "partner"
                    person2["household_id"] = hh_id

                    # Add the partner to the household’s member list.
                    household["members"].append(person2)

# %% [markdown]
# ##Shared_Household
# The shared_household() function implements compatibility algorithm that evaluates potential simmilar members of a shared household

# %%
def shared_household(pop,processed,household,hh_size,person1,hh_id):
    potential = []
    for p in pop:
        # Compute similarity (e.g., age, interests, socioeconomic status).
        similarity = calculate_similarity_score_non_gender (person1, p)
        # Only keep candidates that are sufficiently similar.
        if similarity > 0.3:
            potential.append(p)
    for i in range(hh_size):
        if potential:
            person2 = random.choice(potential)
            # Remove the chosen partner from the pool and record them.
            if person2 in pop:
                pop.remove(person2)
                processed.append(person2)

                # Update partner metadata.
                person2["in_household"] = True
                person2["relationship"] = "partner"
                person2["household_id"] = hh_id

                # Add the partner to the household’s member list.
                household["members"].append(person2)

# %% [markdown]
# ##Couple
# couple() Calls the calculate_similarity_score for all families

# %%
def couple(pop,processed,household,hh_size,person1,hh_id):
    potential = []
    for p in pop:
        # Compute similarity (e.g., age, interests, socioeconomic status).
        similarity = calculate_similarity_score(person1, p)
        # Only keep candidates that are sufficiently similar.
        if similarity > 0.3:
            potential.append(p)

    # If we found at least one candidate, pick one at random.
    if potential:
        person2 = random.choice(potential)
        # Remove the chosen partner from the pool and record them.
        if person2 in pop:
            pop.remove(person2)
            processed.append(person2)

            # Update partner metadata.
            person2["in_household"] = True
            person2["relationship"] = "partner"
            person2["household_id"] = hh_id

            # Add the partner to the household’s member list.
            household["members"].append(person2)

# %% [markdown]
# ##Household formation
# Main household formation pipeline. Generates individuals for an area, then organizes them into households through sequential assignment. Each household starts with a randomly selected "head," then optionally adds a compatible partner based on similarity scoring and family ratio probability. Returns two complementary views: a flat list of all individuals with household assignments, and a structured collection of household groups with metadata. Creates realistic family units while preserving demographic distributions.

# %%
def create_area_population(area_type, urban,area_id, population):
    """
    Generate a list of individuals for a given area and then group them
    into households.

    Parameters
    ----------
    area_type : str
        The type/category of the area (e.g., “city”, “rural”).
    area_id   : str
        Unique identifier for the area – also used as a prefix for household IDs.
    urban     : bool
        Flag indicating whether the area is urban (True) or rural (False).
    population: int
        Desired number of individuals to generate for the area.

    Returns
    -------
    processed   : list
        All individuals after they have been assigned to households.
    households  : list
        A collection of household dictionaries, each containing its members.
    """

    # ----------------------------------------------------------------------
    # 1 GENERATE BASE POPULATION
    # ----------------------------------------------------------------------
    # Create initial pool of individuals with demographic attributes
    # generate_individuals() uses roulette wheel selection to ensure
    # demographic mix matches area_type["demographic_distribution"]
    pop = generate_individuals(area_type, area_id, population)

    # Containers for final results
    processed = []          # All individuals after household assignment
    households = []         # Structured household data
    households_count = 0    # Counter for unique household IDs

    # ----------------------------------------------------------------------
    # 2 HOUSEHOLD FORMATION LOOP
    # ----------------------------------------------------------------------
    # Continue until all individuals are placed in households
    while len(pop) > 0:
        # Create unique household identifier
        hh_id = f"{area_id}_hh{households_count}"

        # --------------------------------------------------------------
        # 2a SELECT HOUSEHOLD HEAD AND DETERMINE HOUSEHOLD TYPE
        # --------------------------------------------------------------
        # Randomly select an individual to become household head
        person1 = random.choice(pop)

        # Get area-specific household type probabilities
        area_household_probs = area_type["household_type_distribution"]

        # Get individual's demographic profile
        demographic = person1["demographic_id"]

        # --------------------------------------------------------------
        # PROBABILITY-BLENDING FOR HOUSEHOLD TYPE SELECTION
        # --------------------------------------------------------------
        # Retrieve individual's demographic profile household probabilities
        person_household_probs = demographic_profiles[demographic]["household_type_probabilities"]

        # Combine individual and area probabilities using Bayesian multiplication
        # combine_probabilities() returns:
        # - hh_types: list of household type keys
        # - hh_probabilities: cumulative probabilities for roulette wheel selection
        hh_types, hh_probabilities = combine_probabilities(
            person_household_probs,
            area_household_probs
        )

        # Roulette wheel selection for household type
        hh_prob = random.random() * max(hh_probabilities)
        indx = 0
        while hh_prob > hh_probabilities[indx]:
            indx += 1
        hh_type_key = hh_types[indx]  # Selected household type (e.g., "nuclear_family")

        # Get full household type definition
        hh_type = household_types[hh_type_key]

        # --------------------------------------------------------------
        # DETERMINE HOUSEHOLD SIZE
        # --------------------------------------------------------------
        # Use household type's size distribution to determine number of occupants
        size_distribution = hh_type["size_distribution"]

        # Build roulette wheel for size selection
        wheel = []
        sizes = []
        count = 0
        for key, value in size_distribution.items():
            count += value
            sizes.append(key)       # Possible sizes (e.g., [1, 2, 3, 4])
            wheel.append(count)     # Cumulative probabilities

        # Roulette wheel selection for household size
        occupants_rnd = random.random() * max(wheel)
        indx = 0
        while occupants_rnd > wheel[indx]:
            indx += 1
        hh_size = sizes[indx]  # Final household size

        # --------------------------------------------------------------
        # 2b INITIALIZE HOUSEHOLD WITH HEAD
        # --------------------------------------------------------------
        # Update head's metadata
        person1["in_household"] = True
        person1["relationship"] = "head"
        person1["household_id"] = hh_id

        # Move head from pool to processed list
        processed.append(person1)
        pop.remove(person1)

        # Create household dictionary with head as first member
        household = {
            "area_id":area_id,
            "hh_id": hh_id,
            "urban": urban,
            "members": [person1],  # Start with head only
        }

        # --------------------------------------------------------------
        # 2c ADD ADDITIONAL HOUSEHOLD MEMBERS BASED ON TYPE
        # --------------------------------------------------------------
        # Note: hh_size includes the head, so we need to add (hh_size - 1) members

        if hh_type_key in ["nuclear_family", "couple_no_children"]:
            # COUPLE-BASED HOUSEHOLDS: Find compatible romantic partner
            # couple() adds 1 partner (if available) based on similarity scoring
            couple(pop, processed, household, hh_size, person1, hh_id)

        elif hh_type_key == "multi_generational":
            # MULTI-GENERATIONAL: Add partner first, then older household members
            # multi_generational() adds partner + (hh_size-2) older members
            multi_generational(pop, processed, household, hh_size, person1, hh_id)

        elif hh_type_key == "shared_household":
            # SHARED HOUSEHOLD: Add compatible non-romantic housemates
            # shared_household() adds (hh_size-1) members based on similarity
            shared_household(pop, processed, household, hh_size, person1, hh_id)

        # Note: "single_person" households require no additional members

        # --------------------------------------------------------------
        # 2d FINALIZE AND STORE HOUSEHOLD
        # --------------------------------------------------------------
        # Record actual household size (may differ from target if insufficient candidates)
        household["size"] = len(household["members"])

        # Add to households collection
        households.append(household)
        households_count += 1

    # ----------------------------------------------------------------------
    # 3 RETURN RESULTS
    # ----------------------------------------------------------------------
    return processed, households

# %%
def calculate_census(households,area_id):
    """
    Compute a set of summary statistics for a collection of households.

    Parameters
    ----------
    households : list[dict]
        Each household dictionary must contain:
          - "members": a list of member dictionaries
          - "urban":   a boolean (True if the household is urban)

        Each member dictionary must contain:
          - "gender": 0 for male, 1 for female
          - "age":    integer age in years
    Returns
    -------
    dict
        Aggregated counts such as total population, number of urban/rural
        households, size‑distribution of households, and age‑by‑gender bins.
    """

    # ------------------------------------------------------------------
    # Initialise all counters to zero
    # ------------------------------------------------------------------
    population       = 0   # total number of individuals
    hh_population    = 0   # total number of households processed

    location_urban   = 0   # count of urban households
    location_rural   = 0   # count of rural households

    # Household‑size distribution (1‑person, 2‑person, …)
    hh_size1 = 0
    hh_size2 = 0
    hh_size3 = 0
    hh_size4 = 0   # “4 or more” bucket

    # Age‑by‑gender buckets (male/female, three age ranges)
    m_0_to_30   = 0
    f_0_to_30   = 0
    m_30_to_60  = 0
    f_30_to_60  = 0
    m_gt_60     = 0
    f_gt_60     = 0
    
    # Education
    edu_non     = 0 
    edu_low     = 0 
    edu_middle  = 0 
    edu_high    = 0
    # ------------------------------------------------------------------
    # Iterate over every household in the input list
    # ------------------------------------------------------------------
    for h in households:
        # --------------------------------------------------------------
        # Household‑level calculations
        # --------------------------------------------------------------
        hh_size = len(h["members"])   # how many people live here?
        hh_population += 1            # we’ve seen another household
        population += hh_size         # add its members to the total pop

        # Urban vs. rural classification
        if h["urban"]:
            location_urban += 1
        else:
            location_rural += 1

        # Update the household‑size histogram
        if hh_size == 1:
            hh_size1 += 1
        elif hh_size == 2:
            hh_size2 += 1
        elif hh_size == 3:
            hh_size3 += 1
        else:
            hh_size4 += hh_size

        # --------------------------------------------------------------
        # Member‑level calculations (age & gender breakdown)
        # --------------------------------------------------------------
        for m in h["members"]:
            gender = m["gender"]   # 0 = male, 1 = female
            age    = m["age"]
            edu    = m["education"]

            # Male branch
            if gender == 0:
                if age < 30:
                    m_0_to_30 += 1
                elif age < 60:
                    m_30_to_60 += 1
                else:
                    m_gt_60 += 1
            # Female branch
            else:
                if age < 30:
                    f_0_to_30 += 1
                elif age < 60:
                    f_30_to_60 += 1
                else:
                    f_gt_60 += 1
            
            #Education
            if edu == 0:
                edu_non+=1
            elif edu <=2:
                edu_low+=1 
            elif edu <=6:
                edu_middle+=1 
            else:
                edu_high+=1
                

    # ------------------------------------------------------------------
    # Pack everything into a dictionary for easy downstream consumption
    # ------------------------------------------------------------------
    return {
        "area_id":   area_id,
        "population":      len(households),
        "location_urban":  location_urban,
        "location_rural":  location_rural,
        "hh_size1":        hh_size1,
        "hh_size2":        hh_size2,
        "hh_size3":        hh_size3,
        "hh_size4":        hh_size4,
        "m_0_to_30":       m_0_to_30,
        "f_0_to_30":       f_0_to_30,
        "m_30_to_60":      m_30_to_60,
        "f_30_to_60":      f_30_to_60,
        "m_gt_60":         m_gt_60,
        "f_gt_60":         f_gt_60,
        "edu_non":         edu_non,
        "edu_low":         edu_low, 
        "edu_middle":      edu_middle,
        "edu_high":        edu_high
    }

# %%
def calculate_survey(household):
    """
    Produce summary statistics for a *single* household that came from a survey.

    Parameters
    ----------
    household : dict
        Expected keys:
            - "hh_id"   : unique identifier for the household
            - "urban"   : bool  True if the household is urban, False otherwise
            - "members" : list of member dicts, each with:
                  * "gender" (0 = male, 1 = female)
                  * "age"    (integer)

    Returns
    -------
    tuple(dict, list)
        1 A dictionary containing aggregated counts for this household.
        2 The original ``members`` list (so the caller still has the raw data).
    """

    # ------------------------------------------------------------------
    # Initialise all counters to zero
    # ------------------------------------------------------------------
    location_urban = 0
    location_rural = 0

    # Household‑size distribution (1‑person, 2‑person, 3‑person, 4+)
    hh_size1 = 0
    hh_size2 = 0
    hh_size3 = 0
    hh_size4 = 0   # “4 or more” bucket

    # Age‑by‑gender buckets
    m_0_to_30 = 0
    f_0_to_30 = 0
    m_30_to_60 = 0
    f_30_to_60 = 0
    m_gt_60 = 0
    f_gt_60 = 0

    # Education
    edu_non     = 0 
    edu_low     = 0 
    edu_middle  = 0 
    edu_high    = 0

    # ------------------------------------------------------------------
    # Extract basic household metadata
    # ------------------------------------------------------------------
    hh_id   = household["hh_id"]
    hh_size = len(household["members"])

    # Urban vs. rural classification
    if household["urban"]:
        location_urban += 1
    else:
        location_rural += 1

    # Update the household‑size histogram
    if hh_size == 1:
        hh_size1 += 1
    elif hh_size == 2:
        hh_size2 += 1
    elif hh_size == 3:
        hh_size3 += 1
    else:
        hh_size4 += hh_size

    # ------------------------------------------------------------------
    # Loop over each member to fill the gender/age buckets
    # ------------------------------------------------------------------
    for m in household["members"]:
        gender = m["gender"]   # 0 = male, 1 = female
        age    = m["age"]
        edu    = m["education"]

        if gender == 0:        # ----- Male -----
            if age < 30:
                m_0_to_30 += 1
            elif age < 60:
                m_30_to_60 += 1
            else:
                m_gt_60 += 1
        else:                  # ----- Female -----
            if age < 30:
                f_0_to_30 += 1
            elif age < 60:
                f_30_to_60 += 1
            else:
                f_gt_60 += 1

        #Education
        if edu == 0:
            edu_non+=1
        elif edu <=2:
            edu_low+=1 
        elif edu <=6:
            edu_middle+=1 
        else:
            edu_high+=1

    # ------------------------------------------------------------------
    # Assemble the result dictionary
    # ------------------------------------------------------------------
    summary = {
        "hh_id":          hh_id,
        "location_urban": location_urban,
        "location_rural": location_rural,
        "hh_size1":       hh_size1,
        "hh_size2":       hh_size2,
        "hh_size3":       hh_size3,
        "hh_size4":       hh_size4,
        "m_0_to_30":      m_0_to_30,
        "f_0_to_30":      f_0_to_30,
        "m_30_to_60":     m_30_to_60,
        "f_30_to_60":     f_30_to_60,
        "m_gt_60":        m_gt_60,
        "f_gt_60":        f_gt_60,
        "edu_non":         edu_non,
        "edu_low":         edu_low, 
        "edu_middle":      edu_middle,
        "edu_high":        edu_high
    }

    # Return both the aggregated stats and the raw member list
    return summary, household["members"]

# %%
with open("bounded_polygons.geojson", "r", encoding="utf-8") as f:
    geojson_obj = json.load(f)
population = []
households=[]
census =[]
for t in geojson_obj["features"]:
    area_type =t["properties"]["type"]
    urban = t["properties"]["urban"]
    area_id = "d"+str(t["properties"]["id"])
    local_population, local_households = create_area_population(area_types[area_type],urban,area_id,t["properties"]["population"])
    house_hold_census = calculate_census(local_households,area_id)
    census.append(house_hold_census)
    population= population+local_population
    households=households+local_households

# %%
print("done")
# Out:
# done

# %%
def dicts_to_csv(dict_list: list[dict], outfile: str | Path) -> None:
    """
    Write *dict_list* to *outfile* as a CSV.

    • All dictionaries should share the same set of keys – those keys are used
      as the header row.
    • Missing keys in a particular row are written as empty cells.
    • The function overwrites *outfile* if it already exists.
    """
    if not dict_list:
        raise ValueError("The input list is empty – nothing to write.")

    # Preserve the order of keys as they appear in the first dict.
    # (Python 3.7+ guarantees dict order is insertion order.)
    fieldnames = list(dict_list[0].keys())

    # Ensure every dict has the same keys – fill missing ones with None.
    normalized = [
        {k: d.get(k, None) for k in fieldnames} for d in dict_list
    ]

    with open(outfile, mode="w", newline="", encoding="utf-8") as fp:
        writer = csv.DictWriter(fp, fieldnames=fieldnames)
        writer.writeheader()
        writer.writerows(normalized)

# %%
dicts_to_csv(census, "artifical_cencus.csv")

# %%
dicts_to_csv(population, "artifical_population.csv")

# %%
survay = random.sample(households, int(len(households)/100))

# %%
len(survay)
# Out:
# 561

# %%
hh_survay = []
for hh in survay:
    hh_data,members =calculate_survey(hh)
    hh_survay.append(hh_data)

# %%
dicts_to_csv(hh_survay, "artifical_survay.csv")

# %%
600*500
# Out:
# 300000

# %%
population
# Out:
# [{'id': 'd0_364',
#   'demographic_id': 'working_class',
#   'age': 56,
#   'education': 2,
#   'gender': 1,
#   'ethnicity': 0,
#   'family_ratio': 0.65,
#   'income': 20751,
#   'in_household': True,
#   'household_id': 'd0_hh0',
#   'relationship': 'head'},
#  {'id': 'd0_102',
#   'demographic_id': 'retired',
#   'age': 69,
#   'education': 4,
#   'gender': 1,
#   'ethnicity': 0,
#   'family_ratio': 0.3,
#   'income': 27826,
#   'in_household': True,
#   'household_id': 'd0_hh0',
#   'relationship': 'partner'},
#  {'id': 'd0_349',
#   'demographic_id': 'working_class',
#   'age': 53,
#   'education': 1,
#   'gender': 0,
#   'ethnicity': 0,
#   'family_ratio': 0.65,
#   'income': 29500,
#   'in_household': True,
#   'household_id': 'd0_hh1',
#   'relationship': 'head'},
#  {'id': 'd0_53',
#   'demographic_id': 'rural_worker',
#   'age': 32,
#   'education': 1,
#   'gender': 1,
#   'ethnicity': 0,
#   'family_ratio': 0.7,
#   'income': 16923,
#   'in_household': True,
#   'household_id': 'd0_hh1',
#   'relationship': 'partner'},
#  {'id': 'd0_310',
#   'demographic_id': 'working_class',
#   'age': 48,
#   'education': 3,
#   'gender': 1,
#   'ethnicity': 0,
#   'family_ratio': 0.65,
#   'income': 35322,
#   'in_household': True,
#   'household_id': 'd0_hh2',
#   'relationship': 'head'},
#  {'id': 'd0_238',
#   'demographic_id': 'retired',
#   'age': 70,
#   'education': 0,
#   'gender': 0,
#   'ethnicity': 0,
#   'family_ratio': 0.3,
#   'income': 6365,
#   'in_household': True,
#   'household_id': 'd0_hh2',
#   'relationship': 'partner'},
#  {'id': 'd0_134',
#   'demographic_id': 'rural_worker',
#   'age': 55,
#   'education': 1,
#   'gender': 1,
#   'ethnicity': 0,
#   'family_ratio': 0.7,
#   'income': 25648,
#   'in_household': True,
#   'household_id': 'd0_hh3',
#   'relationship': 'head'},
#  {'id': 'd0_240',
#   'demographic_id': 'retired',
#   'age': 71,
#   'education': 4,
#   'gender': 0,
#   'ethnicity': 0,
#   'family_ratio': 0.3,
#   'income': -807,
#   'in_household': True,
#   'household_id': 'd0_hh4',
#   'relationship': 'head'},
#  {'id': 'd0_282',
#   'demographic_id': 'farmer_agricultural',
#   'age': 90,
#   'education': 2,
#   'gender': 1,
#   'ethnicity': 0,
#   'family_ratio': 0.75,
#   'income': 17391,
#   'in_household': True,
#   'household_id': 'd0_hh4',
#   'relationship': 'partner'},
#  {'id': 'd0_20',
#   'demographic_id': 'farmer_agricultural',
#   'age': 31,
#   'education': 1,
#   'gender': 0,
#   'ethnicity': 0,
#   'family_ratio': 0.75,
#   'income': 30441,
#   'in_household': True,
#   'household_id': 'd0_hh5',
#   'relationship': 'head'},
#  {'id': 'd0_235',
#   'demographic_id': 'working_class',
#   'age': 37,
#   'education': 1,
#   'gender': 0,
#   'ethnicity': 0,
#   'family_ratio': 0.65,
#   'income': 30468,
#   'in_household': True,
#   'household_id': 'd0_hh5',
#   'relationship': 'partner'},
#  {'id': 'd0_91',
#   'demographic_id': 'rural_worker',
#   'age': 69,
#   'education': 3,
#   'gender': 1,
#   'ethnicity': 0,
#   'family_ratio': 0.7,
#   'income': 24700,
#   'in_household': True,
#   'household_id': 'd0_hh6',
#   'relationship': 'head'},
#  {'id': 'd0_166',
#   'demographic_id': 'working_class',
#   'age': 26,
#   'education': 0,
#   'gender': 0,
#   'ethnicity': 0,
#   'family_ratio': 0.65,
#   'income': 36910,
#   'in_household': True,
#   'household_id': 'd0_hh6',
#   'relationship': 'partner'},
#  {'id': 'd0_420',
#   'demographic_id': 'retired',
#   'age': 79,
#   'education': 2,
#   'gender': 1,
#   'ethnicity': 0,
#   'family_ratio': 0.3,
#   'income': 29957,
#   'in_household': True,
#   'household_id': 'd0_hh7',
#   'relationship': 'head'},
#  {'id': 'd0_93',
#   'demographic_id': 'farmer_agricultural',
#   'age': 55,
#   'education': 2,
#   'gender': 1,
#   'ethnicity': 0,
#   'family_ratio': 0.75,
#   'income': 1831,
#   'in_household': True,
#   'household_id': 'd0_hh7',
#   'relationship': 'partner'},
#  {'id': 'd0_213',
#   'demographic_id': 'working_class',
#   'age': 53,
#   'education': 0,
#   'gender': 0,
#   'ethnicity': 0,
#   'family_ratio': 0.65,
#   'income': 31593,
#   'in_household': True,
#   'household_id': 'd0_hh8',
#   'relationship': 'head'},
#  {'id': 'd0_80',
#   'demographic_id': 'rural_worker',
#   'age': 36,
#   'education': 1,
#   'gender': 0,
#   'ethnicity': 0,
#   'family_ratio': 0.7,
#   'income': 9695,
#   'in_household': True,
#   'household_id': 'd0_hh8',
#   'relationship': 'partner'},
#  {'id': 'd0_167',
#   'demographic_id': 'retired',
#   'age': 79,
#   'education': 1,
#   'gender': 0,
#   'ethnicity': 0,
#   'family_ratio': 0.3,
#   'income': 6974,
#   'in_household': True,
#   'household_id': 'd0_hh9',
#   'relationship': 'head'},
#  {'id': 'd0_512',
#   'demographic_id': 'rural_worker',
#   'age': 54,
#   'education': 0,
#   'gender': 1,
#   'ethnicity': 0,
#   'family_ratio': 0.7,
#   'income': 15488,
#   'in_household': True,
#   'household_id': 'd0_hh9',
#   'relationship': 'partner'},
#  {'id': 'd0_386',
#   'demographic_id': 'working_class',
#   'age': 21,
#   'education': 0,
#   'gender': 1,
#   'ethnicity': 0,
#   'family_ratio': 0.65,
#   'income': 16503,
#   'in_household': True,
#   'household_id': 'd0_hh10',
#   'relationship': 'head'},
#  {'id': 'd0_52',
#   'demographic_id': 'working_class',
#   'age': 49,
#   'education': 3,
#   'gender': 0,
#   'ethnicity': 0,
#   'family_ratio': 0.65,
#   'income': 22005,
#   'in_household': True,
#   'household_id': 'd0_hh10',
#   'relationship': 'partner'},
#  {'id': 'd0_355',
#   'demographic_id': 'farmer_agricultural',
#   'age': 51,
#   'education': 0,
#   'gender': 0,
#   'ethnicity': 0,
#   'family_ratio': 0.75,
#   'income': 34825,
#   'in_household': True,
#   'household_id': 'd0_hh11',
#   'relationship': 'head'},
#  {'id': 'd0_373',
#   'demographic_id': 'affluent_professional',
#   'age': 33,
#   'education': 7,
#   'gender': 1,
#   'ethnicity': 0,
#   'family_ratio': 0.6,
#   'income': 65062,
#   'in_household': True,
#   'household_id': 'd0_hh11',
#   'relationship': 'partner'},
#  {'id': 'd0_142',
#   'demographic_id': 'retired',
#   'age': 78,
#   'education': 5,
#   'gender': 1,
#   'ethnicity': 0,
#   'family_ratio': 0.3,
#   'income': 8178,
#   'in_household': True,
#   'household_id': 'd0_hh12',
#   'relationship': 'head'},
#  {'id': 'd0_340',
#   'demographic_id': 'retired',
#   'age': 74,
#   'education': 3,
#   'gender': 1,
#   'ethnicity': 0,
#   'family_ratio': 0.3,
#   'income': 26098,
#   'in_household': True,
#   'household_id': 'd0_hh12',
#   'relationship': 'partner'},
#  {'id': 'd0_462',
#   'demographic_id': 'middle_class',
#   'age': 57,
#   'education': 2,
#   'gender': 0,
#   'ethnicity': 0,
#   'family_ratio': 0.7,
#   'income': 42036,
#   'in_household': True,
#   'household_id': 'd0_hh13',
#   'relationship': 'head'},
#  {'id': 'd0_319',
#   'demographic_id': 'rural_worker',
#   'age': 70,
#   'education': 1,
#   'gender': 0,
#   'ethnicity': 0,
#   'family_ratio': 0.7,
#   'income': 24856,
#   'in_household': True,
#   'household_id': 'd0_hh13',
#   'relationship': 'partner'},
#  {'id': 'd0_331',
#   'demographic_id': 'retired',
#   'age': 82,
#   'education': 2,
#   'gender': 1,
#   'ethnicity': 0,
#   'family_ratio': 0.3,
#   'income': 25527,
#   'in_household': True,
#   'household_id': 'd0_hh14',
#   'relationship': 'head'},
#  {'id': 'd0_285',
#   'demographic_id': 'retired',
#   'age': 72,
#   'education': 3,
#   'gender': 1,
#   'ethnicity': 0,
#   'family_ratio': 0.3,
#   'income': 26249,
#   'in_household': True,
#   'household_id': 'd0_hh15',
#   'relationship': 'head'},
#  {'id': 'd0_183',
#   'demographic_id': 'middle_class',
#   'age': 51,
#   'education': 5,
#   'gender': 0,
#   'ethnicity': 0,
#   'family_ratio': 0.7,
#   'income': 44678,
#   'in_household': True,
#   'household_id': 'd0_hh15',
#   'relationship': 'partner'},
#  {'id': 'd0_177',
#   'demographic_id': 'working_class',
#   'age': 37,
#   'education': 1,
#   'gender': 0,
#   'ethnicity': 0,
#   'family_ratio': 0.65,
#   'income': 29618,
#   'in_household': True,
#   'household_id': 'd0_hh16',
#   'relationship': 'head'},
#  {'id': 'd0_346',
#   'demographic_id': 'farmer_agricultural',
#   'age': 61,
#   'education': 2,
#   'gender': 0,
#   'ethnicity': 0,
#   'family_ratio': 0.75,
#   'income': 13678,
#   'in_household': True,
#   'household_id': 'd0_hh17',
#   'relationship': 'head'},
#  {'id': 'd0_490',
#   'demographic_id': 'farmer_agricultural',
#   'age': 53,
#   'education': 3,
#   'gender': 1,
#   'ethnicity': 0,
#   'family_ratio': 0.75,
#   'income': 27798,
#   'in_household': True,
#   'household_id': 'd0_hh17',
#   'relationship': 'partner'},
#  {'id': 'd0_79',
#   'demographic_id': 'farmer_agricultural',
#   'age': 50,
#   'education': 0,
#   'gender': 1,
#   'ethnicity': 0,
#   'family_ratio': 0.75,
#   'income': 20058,
#   'in_household': True,
#   'household_id': 'd0_hh18',
#   'relationship': 'head'},
#  {'id': 'd0_482',
#   'demographic_id': 'working_class',
#   'age': 73,
#   'education': 4,
#   'gender': 1,
#   'ethnicity': 0,
#   'family_ratio': 0.65,
#   'income': 23547,
#   'in_household': True,
#   'household_id': 'd0_hh18',
#   'relationship': 'partner'},
#  {'id': 'd0_225',
#   'demographic_id': 'farmer_agricultural',
#   'age': 56,
#   'education': 4,
#   'gender': 0,
#   'ethnicity': 0,
#   'family_ratio': 0.75,
#   'income': 34302,
#   'in_household': True,
#   'household_id': 'd0_hh19',
#   'relationship': 'head'},
#  {'id': 'd0_2',
#   'demographic_id': 'farmer_agricultural',
#   'age': 53,
#   'education': 1,
#   'gender': 0,
#   'ethnicity': 0,
#   'family_ratio': 0.75,
#   'income': 27747,
#   'in_household': True,
#   'household_id': 'd0_hh19',
#   'relationship': 'partner'},
#  {'id': 'd0_454',
#   'demographic_id': 'farmer_agricultural',
#   'age': 31,
#   'education': 2,
#   'gender': 0,
#   'ethnicity': 0,
#   'family_ratio': 0.75,
#   'income': 22304,
#   'in_household': True,
#   'household_id': 'd0_hh20',
#   'relationship': 'head'},
#  {'id': 'd0_321',
#   'demographic_id': 'working_class',
#   'age': 46,
#   'education': 2,
#   'gender': 1,
#   'ethnicity': 0,
#   'family_ratio': 0.65,
#   'income': 15082,
#   'in_household': True,
#   'household_id': 'd0_hh20',
#   'relationship': 'partner'},
#  {'id': 'd0_348',
#   'demographic_id': 'rural_worker',
#   'age': 37,
#   'education': 1,
#   'gender': 0,
#   'ethnicity': 0,
#   'family_ratio': 0.7,
#   'income': 18236,
#   'in_household': True,
#   'household_id': 'd0_hh21',
#   'relationship': 'head'},
#  {'id': 'd0_368',
#   'demographic_id': 'retired',
#   'age': 63,
#   'education': 3,
#   'gender': 1,
#   'ethnicity': 0,
#   'family_ratio': 0.3,
#   'income': 8441,
#   'in_household': True,
#   'household_id': 'd0_hh21',
#   'relationship': 'partner'},
#  {'id': 'd0_334',
#   'demographic_id': 'rural_worker',
#   'age': 41,
#   'education': 2,
#   'gender': 0,
#   'ethnicity': 0,
#   'family_ratio': 0.7,
#   'income': 22020,
#   'in_household': True,
#   'household_id': 'd0_hh22',
#   'relationship': 'head'},
#  {'id': 'd0_162',
#   'demographic_id': 'rural_worker',
#   'age': 37,
#   'education': 2,
#   'gender': 1,
#   'ethnicity': 0,
#   'family_ratio': 0.7,
#   'income': 16039,
#   'in_household': True,
#   'household_id': 'd0_hh22',
#   'relationship': 'partner'},
#  {'id': 'd0_119',
#   'demographic_id': 'rural_worker',
#   'age': 48,
#   'education': 1,
#   'gender': 1,
#   'ethnicity': 0,
#   'family_ratio': 0.7,
#   'income': 20967,
#   'in_household': True,
#   'household_id': 'd0_hh23',
#   'relationship': 'head'},
#  {'id': 'd0_288',
#   'demographic_id': 'retired',
#   'age': 66,
#   'education': 4,
#   'gender': 0,
#   'ethnicity': 0,
#   'family_ratio': 0.3,
#   'income': 8578,
#   'in_household': True,
#   'household_id': 'd0_hh23',
#   'relationship': 'partner'},
#  {'id': 'd0_294',
#   'demographic_id': 'affluent_professional',
#   'age': 32,
#   'education': 5,
#   'gender': 1,
#   'ethnicity': 0,
#   'family_ratio': 0.6,
#   'income': 43133,
#   'in_household': True,
#   'household_id': 'd0_hh24',
#   'relationship': 'head'},
#  {'id': 'd0_354',
#   'demographic_id': 'working_class',
#   'age': 42,
#   'education': 3,
#   'gender': 1,
#   'ethnicity': 0,
#   'family_ratio': 0.65,
#   'income': 20845,
#   'in_household': True,
#   'household_id': 'd0_hh24',
#   'relationship': 'partner'},
#  {'id': 'd0_381',
#   'demographic_id': 'farmer_agricultural',
#   'age': 45,
#   'education': 2,
#   'gender': 1,
#   'ethnicity': 0,
#   'family_ratio': 0.75,
#   'income': 38351,
#   'in_household': True,
#   'household_id': 'd0_hh25',
#   'relationship': 'head'},
#  {'id': 'd0_202',
#   'demographic_id': 'working_class',
#   'age': 56,
#   'education': 3,
#   'gender': 0,
#   'ethnicity': 0,
#   'family_ratio': 0.65,
#   'income': 12515,
#   'in_household': True,
#   'household_id': 'd0_hh25',
#   'relationship': 'partner'},
#  {'id': 'd0_208',
#   'demographic_id': 'working_class',
#   'age': 53,
#   'education': 1,
#   'gender': 0,
#   'ethnicity': 0,
#   'family_ratio': 0.65,
#   'income': 22706,
#   'in_household': True,
#   'household_id': 'd0_hh26',
#   'relationship': 'head'},
#  {'id': 'd0_234',
#   'demographic_id': 'rural_worker',
#   'age': 34,
#   'education': 1,
#   'gender': 1,
#   'ethnicity': 0,
#   'family_ratio': 0.7,
#   'income': 29344,
#   'in_household': True,
#   'household_id': 'd0_hh26',
#   'relationship': 'partner'},
#  {'id': 'd0_367',
#   'demographic_id': 'farmer_agricultural',
#   'age': 59,
#   'education': 2,
#   'gender': 0,
#   'ethnicity': 0,
#   'family_ratio': 0.75,
#   'income': 35794,
#   'in_household': True,
#   'household_id': 'd0_hh27',
#   'relationship': 'head'},
#  {'id': 'd0_221',
#   'demographic_id': 'middle_class',
#   'age': 41,
#   'education': 4,
#   'gender': 0,
#   'ethnicity': 0,
#   'family_ratio': 0.7,
#   'income': 17532,
#   'in_household': True,
#   'household_id': 'd0_hh28',
#   'relationship': 'head'},
#  {'id': 'd0_320',
#   'demographic_id': 'farmer_agricultural',
#   'age': 71,
#   'education': 2,
#   'gender': 0,
#   'ethnicity': 0,
#   'family_ratio': 0.75,
#   'income': 12964,
#   'in_household': True,
#   'household_id': 'd0_hh28',
#   'relationship': 'partner'},
#  {'id': 'd0_195',
#   'demographic_id': 'farmer_agricultural',
#   'age': 75,
#   'education': 0,
#   'gender': 0,
#   'ethnicity': 0,
#   'family_ratio': 0.75,
#   'income': 15438,
#   'in_household': True,
#   'household_id': 'd0_hh29',
#   'relationship': 'head'},
#  {'id': 'd0_426',
#   'demographic_id': 'working_class',
#   'age': 52,
#   'education': 2,
#   'gender': 1,
#   'ethnicity': 0,
#   'family_ratio': 0.65,
#   'income': 35548,
#   'in_household': True,
#   'household_id': 'd0_hh29',
#   'relationship': 'partner'},
#  {'id': 'd0_475',
#   'demographic_id': 'working_class',
#   'age': 37,
#   'education': 3,
#   'gender': 0,
#   'ethnicity': 0,
#   'family_ratio': 0.65,
#   'income': 33369,
#   'in_household': True,
#   'household_id': 'd0_hh30',
#   'relationship': 'head'},
#  {'id': 'd0_39',
#   'demographic_id': 'farmer_agricultural',
#   'age': 52,
#   'education': 3,
#   'gender': 1,
#   'ethnicity': 0,
#   'family_ratio': 0.75,
#   'income': 24409,
#   'in_household': True,
#   'household_id': 'd0_hh30',
#   'relationship': 'partner'},
#  {'id': 'd0_133',
#   'demographic_id': 'working_class',
#   'age': 40,
#   'education': 2,
#   'gender': 1,
#   'ethnicity': 0,
#   'family_ratio': 0.65,
#   'income': 27574,
#   'in_household': True,
#   'household_id': 'd0_hh31',
#   'relationship': 'head'},
#  {'id': 'd0_247',
#   'demographic_id': 'rural_worker',
#   'age': 59,
#   'education': 0,
#   'gender': 1,
#   'ethnicity': 0,
#   'family_ratio': 0.7,
#   'income': 8981,
#   'in_household': True,
#   'household_id': 'd0_hh32',
#   'relationship': 'head'},
#  {'id': 'd0_3',
#   'demographic_id': 'rural_worker',
#   'age': 36,
#   'education': 2,
#   'gender': 0,
#   'ethnicity': 0,
#   'family_ratio': 0.7,
#   'income': 27444,
#   'in_household': True,
#   'household_id': 'd0_hh33',
#   'relationship': 'head'},
#  {'id': 'd0_502',
#   'demographic_id': 'rural_worker',
#   'age': 22,
#   'education': 1,
#   'gender': 0,
#   'ethnicity': 0,
#   'family_ratio': 0.7,
#   'income': 35982,
#   'in_household': True,
#   'household_id': 'd0_hh33',
#   'relationship': 'partner'},
#  {'id': 'd0_215',
#   'demographic_id': 'rural_worker',
#   'age': 44,
#   'education': 2,
#   'gender': 1,
#   'ethnicity': 0,
#   'family_ratio': 0.7,
#   'income': 9885,
#   'in_household': True,
#   'household_id': 'd0_hh34',
#   'relationship': 'head'},
#  {'id': 'd0_261',
#   'demographic_id': 'working_class',
#   'age': 57,
#   'education': 2,
#   'gender': 1,
#   'ethnicity': 0,
#   'family_ratio': 0.65,
#   'income': 27990,
#   'in_household': True,
#   'household_id': 'd0_hh34',
#   'relationship': 'partner'},
#  {'id': 'd0_242',
#   'demographic_id': 'middle_class',
#   'age': 47,
#   'education': 5,
#   'gender': 0,
#   'ethnicity': 0,
#   'family_ratio': 0.7,
#   'income': 24318,
#   'in_household': True,
#   'household_id': 'd0_hh35',
#   'relationship': 'head'},
#  {'id': 'd0_0',
#   'demographic_id': 'farmer_agricultural',
#   'age': 55,
#   'education': 0,
#   'gender': 1,
#   'ethnicity': 0,
#   'family_ratio': 0.75,
#   'income': 39256,
#   'in_household': True,
#   'household_id': 'd0_hh35',
#   'relationship': 'partner'},
#  {'id': 'd0_281',
#   'demographic_id': 'retired',
#   'age': 71,
#   'education': 2,
#   'gender': 0,
#   'ethnicity': 0,
#   'family_ratio': 0.3,
#   'income': 25654,
#   'in_household': True,
#   'household_id': 'd0_hh36',
#   'relationship': 'head'},
#  {'id': 'd0_353',
#   'demographic_id': 'working_class',
#   'age': 52,
#   'education': 2,
#   'gender': 1,
#   'ethnicity': 0,
#   'family_ratio': 0.65,
#   'income': 37632,
#   'in_household': True,
#   'household_id': 'd0_hh37',
#   'relationship': 'head'},
#  {'id': 'd0_472',
#   'demographic_id': 'working_class',
#   'age': 72,
#   'education': 3,
#   'gender': 0,
#   'ethnicity': 0,
#   'family_ratio': 0.65,
#   'income': 33769,
#   'in_household': True,
#   'household_id': 'd0_hh37',
#   'relationship': 'partner'},
#  {'id': 'd0_8',
#   'demographic_id': 'rural_worker',
#   'age': 41,
#   'education': 1,
#   'gender': 1,
#   'ethnicity': 0,
#   'family_ratio': 0.7,
#   'income': 25726,
#   'in_household': True,
#   'household_id': 'd0_hh38',
#   'relationship': 'head'},
#  {'id': 'd0_424',
#   'demographic_id': 'farmer_agricultural',
#   'age': 47,
#   'education': 2,
#   'gender': 1,
#   'ethnicity': 0,
#   'family_ratio': 0.75,
#   'income': 18645,
#   'in_household': True,
#   'household_id': 'd0_hh38',
#   'relationship': 'partner'},
#  {'id': 'd0_481',
#   'demographic_id': 'working_class',
#   'age': 63,
#   'education': 2,
#   'gender': 0,
#   'ethnicity': 0,
#   'family_ratio': 0.65,
#   'income': 28320,
#   'in_household': True,
#   'household_id': 'd0_hh38',
#   'relationship': 'partner'},
#  {'id': 'd0_257',
#   'demographic_id': 'farmer_agricultural',
#   'age': 68,
#   'education': 2,
#   'gender': 1,
#   'ethnicity': 0,
#   'family_ratio': 0.75,
#   'income': 48259,
#   'in_household': True,
#   'household_id': 'd0_hh38',
#   'relationship': 'partner'},
#  {'id': 'd0_244',
#   'demographic_id': 'rural_worker',
#   'age': 52,
#   'education': 1,
#   'gender': 0,
#   'ethnicity': 0,
#   'family_ratio': 0.7,
#   'income': 23947,
#   'in_household': True,
#   'household_id': 'd0_hh39',
#   'relationship': 'head'},
#  {'id': 'd0_13',
#   'demographic_id': 'farmer_agricultural',
#   'age': 59,
#   'education': 2,
#   'gender': 0,
#   'ethnicity': 0,
#   'family_ratio': 0.75,
#   'income': 36147,
#   'in_household': True,
#   'household_id': 'd0_hh39',
#   'relationship': 'partner'},
#  {'id': 'd0_302',
#   'demographic_id': 'middle_class',
#   'age': 42,
#   'education': 2,
#   'gender': 0,
#   'ethnicity': 0,
#   'family_ratio': 0.7,
#   'income': 38839,
#   'in_household': True,
#   'household_id': 'd0_hh40',
#   'relationship': 'head'},
#  {'id': 'd0_196',
#   'demographic_id': 'affluent_professional',
#   'age': 44,
#   'education': 8,
#   'gender': 1,
#   'ethnicity': 0,
#   'family_ratio': 0.6,
#   'income': 40552,
#   'in_household': True,
#   'household_id': 'd0_hh40',
#   'relationship': 'partner'},
#  {'id': 'd0_489',
#   'demographic_id': 'farmer_agricultural',
#   'age': 35,
#   'education': 0,
#   'gender': 1,
#   'ethnicity': 0,
#   'family_ratio': 0.75,
#   'income': 1485,
#   'in_household': True,
#   'household_id': 'd0_hh41',
#   'relationship': 'head'},
#  {'id': 'd0_205',
#   'demographic_id': 'farmer_agricultural',
#   'age': 36,
#   'education': 2,
#   'gender': 0,
#   'ethnicity': 0,
#   'family_ratio': 0.75,
#   'income': 31624,
#   'in_household': True,
#   'household_id': 'd0_hh41',
#   'relationship': 'partner'},
#  {'id': 'd0_50',
#   'demographic_id': 'working_class',
#   'age': 46,
#   'education': 1,
#   'gender': 0,
#   'ethnicity': 0,
#   'family_ratio': 0.65,
#   'income': 12602,
#   'in_household': True,
#   'household_id': 'd0_hh42',
#   'relationship': 'head'},
#  {'id': 'd0_417',
#   'demographic_id': 'rural_worker',
#   'age': 62,
#   'education': 1,
#   'gender': 0,
#   'ethnicity': 0,
#   'family_ratio': 0.7,
#   'income': 24113,
#   'in_household': True,
#   'household_id': 'd0_hh43',
#   'relationship': 'head'},
#  {'id': 'd0_125',
#   'demographic_id': 'retired',
#   'age': 90,
#   'education': 2,
#   'gender': 0,
#   'ethnicity': 0,
#   'family_ratio': 0.3,
#   'income': 1964,
#   'in_household': True,
#   'household_id': 'd0_hh43',
#   'relationship': 'partner'},
#  {'id': 'd0_309',
#   'demographic_id': 'rural_worker',
#   'age': 50,
#   'education': 1,
#   'gender': 0,
#   'ethnicity': 0,
#   'family_ratio': 0.7,
#   'income': 22529,
#   'in_household': True,
#   'household_id': 'd0_hh44',
#   'relationship': 'head'},
#  {'id': 'd0_27',
#   'demographic_id': 'rural_worker',
#   'age': 38,
#   'education': 1,
#   'gender': 1,
#   'ethnicity': 0,
#   'family_ratio': 0.7,
#   'income': 19327,
#   'in_household': True,
#   'household_id': 'd0_hh44',
#   'relationship': 'partner'},
#  {'id': 'd0_425',
#   'demographic_id': 'retired',
#   'age': 72,
#   'education': 1,
#   'gender': 1,
#   'ethnicity': 0,
#   'family_ratio': 0.3,
#   'income': 38200,
#   'in_household': True,
#   'household_id': 'd0_hh45',
#   'relationship': 'head'},
#  {'id': 'd0_313',
#   'demographic_id': 'retired',
#   'age': 78,
#   'education': 3,
#   'gender': 0,
#   'ethnicity': 0,
#   'family_ratio': 0.3,
#   'income': 30863,
#   'in_household': True,
#   'household_id': 'd0_hh46',
#   'relationship': 'head'},
#  {'id': 'd0_456',
#   'demographic_id': 'retired',
#   'age': 81,
#   'education': 4,
#   'gender': 1,
#   'ethnicity': 0,
#   'family_ratio': 0.3,
#   'income': 6852,
#   'in_household': True,
#   'household_id': 'd0_hh47',
#   'relationship': 'head'},
#  {'id': 'd0_371',
#   'demographic_id': 'farmer_agricultural',
#   'age': 49,
#   'education': 2,
#   'gender': 0,
#   'ethnicity': 0,
#   'family_ratio': 0.75,
#   'income': 29184,
#   'in_household': True,
#   'household_id': 'd0_hh47',
#   'relationship': 'partner'},
#  {'id': 'd0_245',
#   'demographic_id': 'middle_class',
#   'age': 46,
#   'education': 5,
#   'gender': 0,
#   'ethnicity': 0,
#   'family_ratio': 0.7,
#   'income': 47684,
#   'in_household': True,
#   'household_id': 'd0_hh48',
#   'relationship': 'head'},
#  {'id': 'd0_204',
#   'demographic_id': 'rural_worker',
#   'age': 30,
#   'education': 2,
#   'gender': 1,
#   'ethnicity': 0,
#   'family_ratio': 0.7,
#   'income': 16353,
#   'in_household': True,
#   'household_id': 'd0_hh48',
#   'relationship': 'partner'},
#  {'id': 'd0_444',
#   'demographic_id': 'affluent_professional',
#   'age': 49,
#   'education': 6,
#   'gender': 0,
#   'ethnicity': 0,
#   'family_ratio': 0.6,
#   'income': 73239,
#   'in_household': True,
#   'household_id': 'd0_hh49',
#   'relationship': 'head'},
#  {'id': 'd0_339',
#   'demographic_id': 'working_class',
#   'age': 44,
#   'education': 2,
#   'gender': 1,
#   'ethnicity': 0,
#   'family_ratio': 0.65,
#   'income': 30957,
#   'in_household': True,
#   'household_id': 'd0_hh50',
#   'relationship': 'head'},
#  {'id': 'd0_306',
#   'demographic_id': 'rural_worker',
#   'age': 60,
#   'education': 0,
#   'gender': 0,
#   'ethnicity': 0,
#   'family_ratio': 0.7,
#   'income': 19774,
#   'in_household': True,
#   'household_id': 'd0_hh50',
#   'relationship': 'partner'},
#  {'id': 'd0_31',
#   'demographic_id': 'retired',
#   'age': 71,
#   'education': 0,
#   'gender': 1,
#   'ethnicity': 0,
#   'family_ratio': 0.3,
#   'income': 7528,
#   'in_household': True,
#   'household_id': 'd0_hh51',
#   'relationship': 'head'},
#  {'id': 'd0_92',
#   'demographic_id': 'rural_worker',
#   'age': 37,
#   'education': 0,
#   'gender': 1,
#   'ethnicity': 0,
#   'family_ratio': 0.7,
#   'income': 30338,
#   'in_household': True,
#   'household_id': 'd0_hh52',
#   'relationship': 'head'},
#  {'id': 'd0_132',
#   'demographic_id': 'rural_worker',
#   'age': 54,
#   'education': 1,
#   'gender': 0,
#   'ethnicity': 0,
#   'family_ratio': 0.7,
#   'income': 25710,
#   'in_household': True,
#   'household_id': 'd0_hh52',
#   'relationship': 'partner'},
#  {'id': 'd0_188',
#   'demographic_id': 'working_class',
#   'age': 57,
#   'education': 3,
#   'gender': 1,
#   'ethnicity': 0,
#   'family_ratio': 0.65,
#   'income': 24722,
#   'in_household': True,
#   'household_id': 'd0_hh53',
#   'relationship': 'head'},
#  {'id': 'd0_317',
#   'demographic_id': 'affluent_professional',
#   'age': 46,
#   'education': 7,
#   'gender': 0,
#   'ethnicity': 0,
#   'family_ratio': 0.6,
#   'income': 41751,
#   'in_household': True,
#   'household_id': 'd0_hh53',
#   'relationship': 'partner'},
#  {'id': 'd0_30',
#   'demographic_id': 'middle_class',
#   'age': 51,
#   'education': 4,
#   'gender': 0,
#   'ethnicity': 0,
#   'family_ratio': 0.7,
#   'income': 32920,
#   'in_household': True,
#   'household_id': 'd0_hh54',
#   'relationship': 'head'},
#  {'id': 'd0_1',
#   'demographic_id': 'retired',
#   'age': 79,
#   'education': 0,
#   'gender': 0,
#   'ethnicity': 0,
#   'family_ratio': 0.3,
#   'income': 8978,
#   'in_household': True,
#   'household_id': 'd0_hh54',
#   'relationship': 'partner'},
#  {'id': 'd0_228',
#   'demographic_id': 'rural_worker',
#   'age': 41,
#   'education': 1,
#   'gender': 0,
#   'ethnicity': 0,
#   'family_ratio': 0.7,
#   'income': 27535,
#   'in_household': True,
#   'household_id': 'd0_hh55',
#   'relationship': 'head'},
#  {'id': 'd0_260',
#   'demographic_id': 'retired',
#   'age': 71,
#   'education': 2,
#   'gender': 0,
#   'ethnicity': 0,
#   'family_ratio': 0.3,
#   'income': 39975,
#   'in_household': True,
#   'household_id': 'd0_hh56',
#   'relationship': 'head'},
#  {'id': 'd0_273',
#   'demographic_id': 'farmer_agricultural',
#   'age': 38,
#   'education': 1,
#   'gender': 0,
#   'ethnicity': 0,
#   'family_ratio': 0.75,
#   'income': 49566,
#   'in_household': True,
#   'household_id': 'd0_hh57',
#   'relationship': 'head'},
#  {'id': 'd0_351',
#   'demographic_id': 'working_class',
#   'age': 74,
#   'education': 0,
#   'gender': 0,
#   'ethnicity': 0,
#   'family_ratio': 0.65,
#   'income': 37776,
#   'in_household': True,
#   'household_id': 'd0_hh57',
#   'relationship': 'partner'},
#  {'id': 'd0_412',
#   'demographic_id': 'rural_worker',
#   'age': 46,
#   'education': 2,
#   'gender': 1,
#   'ethnicity': 0,
#   'family_ratio': 0.7,
#   'income': 26327,
#   'in_household': True,
#   'household_id': 'd0_hh58',
#   'relationship': 'head'},
#  {'id': 'd0_37',
#   'demographic_id': 'retired',
#   'age': 73,
#   'education': 1,
#   'gender': 0,
#   'ethnicity': 0,
#   'family_ratio': 0.3,
#   'income': 7539,
#   'in_household': True,
#   'household_id': 'd0_hh59',
#   'relationship': 'head'},
#  {'id': 'd0_335',
#   'demographic_id': 'affluent_professional',
#   'age': 45,
#   'education': 7,
#   'gender': 1,
#   'ethnicity': 0,
#   'family_ratio': 0.6,
#   'income': 57503,
#   'in_household': True,
#   'household_id': 'd0_hh60',
#   'relationship': 'head'},
#  {'id': 'd0_226',
#   'demographic_id': 'working_class',
#   'age': 52,
#   'education': 2,
#   'gender': 1,
#   'ethnicity': 0,
#   'family_ratio': 0.65,
#   'income': 32534,
#   'in_household': True,
#   'household_id': 'd0_hh60',
#   'relationship': 'partner'},
#  {'id': 'd0_423',
#   'demographic_id': 'retired',
#   'age': 76,
#   'education': 5,
#   'gender': 1,
#   'ethnicity': 0,
#   'family_ratio': 0.3,
#   'income': 36493,
#   'in_household': True,
#   'household_id': 'd0_hh61',
#   'relationship': 'head'},
#  {'id': 'd0_216',
#   'demographic_id': 'affluent_professional',
#   'age': 43,
#   'education': 6,
#   'gender': 0,
#   'ethnicity': 0,
#   'family_ratio': 0.6,
#   'income': 101956,
#   'in_household': True,
#   'household_id': 'd0_hh62',
#   'relationship': 'head'},
#  {'id': 'd0_503',
#   'demographic_id': 'farmer_agricultural',
#   'age': 53,
#   'education': 2,
#   'gender': 0,
#   'ethnicity': 0,
#   'family_ratio': 0.75,
#   'income': 36221,
#   'in_household': True,
#   'household_id': 'd0_hh63',
#   'relationship': 'head'},
#  {'id': 'd0_397',
#   'demographic_id': 'working_class',
#   'age': 59,
#   'education': 2,
#   'gender': 0,
#   'ethnicity': 0,
#   'family_ratio': 0.65,
#   'income': 32000,
#   'in_household': True,
#   'household_id': 'd0_hh63',
#   'relationship': 'partner'},
#  {'id': 'd0_422',
#   'demographic_id': 'retired',
#   'age': 65,
#   'education': 3,
#   'gender': 1,
#   'ethnicity': 0,
#   'family_ratio': 0.3,
#   'income': 28502,
#   'in_household': True,
#   'household_id': 'd0_hh64',
#   'relationship': 'head'},
#  {'id': 'd0_16',
#   'demographic_id': 'farmer_agricultural',
#   'age': 60,
#   'education': 2,
#   'gender': 1,
#   'ethnicity': 0,
#   'family_ratio': 0.75,
#   'income': 32336,
#   'in_household': True,
#   'household_id': 'd0_hh64',
#   'relationship': 'partner'},
#  {'id': 'd0_241',
#   'demographic_id': 'middle_class',
#   'age': 30,
#   'education': 3,
#   'gender': 1,
#   'ethnicity': 0,
#   'family_ratio': 0.7,
#   'income': 55534,
#   'in_household': True,
#   'household_id': 'd0_hh65',
#   'relationship': 'head'},
#  {'id': 'd0_297',
#   'demographic_id': 'farmer_agricultural',
#   'age': 45,
#   'education': 1,
#   'gender': 1,
#   'ethnicity': 0,
#   'family_ratio': 0.75,
#   'income': 28578,
#   'in_household': True,
#   'household_id': 'd0_hh65',
#   'relationship': 'partner'},
#  {'id': 'd0_343',
#   'demographic_id': 'retired',
#   'age': 80,
#   'education': 4,
#   'gender': 0,
#   'ethnicity': 0,
#   'family_ratio': 0.3,
#   'income': 24027,
#   'in_household': True,
#   'household_id': 'd0_hh65',
#   'relationship': 'partner'},
#  {'id': 'd0_280',
#   'demographic_id': 'affluent_professional',
#   'age': 59,
#   'education': 6,
#   'gender': 0,
#   'ethnicity': 0,
#   'family_ratio': 0.6,
#   'income': 100073,
#   'in_household': True,
#   'household_id': 'd0_hh65',
#   'relationship': 'partner'},
#  {'id': 'd0_217',
#   'demographic_id': 'farmer_agricultural',
#   'age': 49,
#   'education': 3,
#   'gender': 1,
#   'ethnicity': 0,
#   'family_ratio': 0.75,
#   'income': 11443,
#   'in_household': True,
#   'household_id': 'd0_hh65',
#   'relationship': 'partner'},
#  {'id': 'd0_248',
#   'demographic_id': 'working_class',
#   'age': 49,
#   'education': 3,
#   'gender': 0,
#   'ethnicity': 0,
#   'family_ratio': 0.65,
#   'income': 40380,
#   'in_household': True,
#   'household_id': 'd0_hh66',
#   'relationship': 'head'},
#  {'id': 'd0_283',
#   'demographic_id': 'middle_class',
#   'age': 54,
#   'education': 3,
#   'gender': 0,
#   'ethnicity': 0,
#   'family_ratio': 0.7,
#   'income': 32122,
#   'in_household': True,
#   'household_id': 'd0_hh67',
#   'relationship': 'head'},
#  {'id': 'd0_414',
#   'demographic_id': 'retired',
#   'age': 85,
#   'education': 2,
#   'gender': 0,
#   'ethnicity': 0,
#   'family_ratio': 0.3,
#   'income': 32448,
#   'in_household': True,
#   'household_id': 'd0_hh67',
#   'relationship': 'partner'},
#  {'id': 'd0_450',
#   'demographic_id': 'farmer_agricultural',
#   'age': 48,
#   'education': 2,
#   'gender': 0,
#   'ethnicity': 0,
#   'family_ratio': 0.75,
#   'income': 8621,
#   'in_household': True,
#   'household_id': 'd0_hh68',
#   'relationship': 'head'},
#  {'id': 'd0_494',
#   'demographic_id': 'retired',
#   'age': 72,
#   'education': 3,
#   'gender': 1,
#   'ethnicity': 0,
#   'family_ratio': 0.3,
#   'income': 29776,
#   'in_household': True,
#   'household_id': 'd0_hh68',
#   'relationship': 'partner'},
#  {'id': 'd0_429',
#   'demographic_id': 'retired',
#   'age': 71,
#   'education': 5,
#   'gender': 0,
#   'ethnicity': 0,
#   'family_ratio': 0.3,
#   'income': 30241,
#   'in_household': True,
#   'household_id': 'd0_hh69',
#   'relationship': 'head'},
#  {'id': 'd0_286',
#   'demographic_id': 'affluent_professional',
#   'age': 24,
#   'education': 7,
#   'gender': 0,
#   'ethnicity': 0,
#   'family_ratio': 0.6,
#   'income': 45359,
#   'in_household': True,
#   'household_id': 'd0_hh70',
#   'relationship': 'head'},
#  {'id': 'd0_4',
#   'demographic_id': 'farmer_agricultural',
#   'age': 52,
#   'education': 3,
#   'gender': 1,
#   'ethnicity': 0,
#   'family_ratio': 0.75,
#   'income': 35012,
#   'in_household': True,
#   'household_id': 'd0_hh70',
#   'relationship': 'partner'},
#  {'id': 'd0_416',
#   'demographic_id': 'retired',
#   'age': 70,
#   'education': 0,
#   'gender': 1,
#   'ethnicity': 0,
#   'family_ratio': 0.3,
#   'income': 31672,
#   'in_household': True,
#   'household_id': 'd0_hh71',
#   'relationship': 'head'},
#  {'id': 'd0_187',
#   'demographic_id': 'retired',
#   'age': 74,
#   'education': 2,
#   'gender': 0,
#   'ethnicity': 0,
#   'family_ratio': 0.3,
#   'income': 14344,
#   'in_household': True,
#   'household_id': 'd0_hh71',
#   'relationship': 'partner'},
#  {'id': 'd0_35',
#   'demographic_id': 'retired',
#   'age': 70,
#   'education': 1,
#   'gender': 1,
#   'ethnicity': 0,
#   'family_ratio': 0.3,
#   'income': 18609,
#   'in_household': True,
#   'household_id': 'd0_hh72',
#   'relationship': 'head'},
#  {'id': 'd0_140',
#   'demographic_id': 'middle_class',
#   'age': 45,
#   'education': 3,
#   'gender': 0,
#   'ethnicity': 0,
#   'family_ratio': 0.7,
#   'income': 30867,
#   'in_household': True,
#   'household_id': 'd0_hh72',
#   'relationship': 'partner'},
#  {'id': 'd0_493',
#   'demographic_id': 'rural_worker',
#   'age': 64,
#   'education': 2,
#   'gender': 1,
#   'ethnicity': 0,
#   'family_ratio': 0.7,
#   'income': 25943,
#   'in_household': True,
#   'household_id': 'd0_hh73',
#   'relationship': 'head'},
#  {'id': 'd0_385',
#   'demographic_id': 'farmer_agricultural',
#   'age': 53,
#   'education': 2,
#   'gender': 0,
#   'ethnicity': 0,
#   'family_ratio': 0.75,
#   'income': 50094,
#   'in_household': True,
#   'household_id': 'd0_hh73',
#   'relationship': 'partner'},
#  {'id': 'd0_163',
#   'demographic_id': 'farmer_agricultural',
#   'age': 59,
#   'education': 3,
#   'gender': 0,
#   'ethnicity': 0,
#   'family_ratio': 0.75,
#   'income': 33497,
#   'in_household': True,
#   'household_id': 'd0_hh74',
#   'relationship': 'head'},
#  {'id': 'd0_83',
#   'demographic_id': 'farmer_agricultural',
#   'age': 37,
#   'education': 1,
#   'gender': 0,
#   'ethnicity': 0,
#   'family_ratio': 0.75,
#   'income': 33123,
#   'in_household': True,
#   'household_id': 'd0_hh74',
#   'relationship': 'partner'},
#  {'id': 'd0_150',
#   'demographic_id': 'farmer_agricultural',
#   'age': 50,
#   'education': 2,
#   'gender': 1,
#   'ethnicity': 0,
#   'family_ratio': 0.75,
#   'income': 57265,
#   'in_household': True,
#   'household_id': 'd0_hh75',
#   'relationship': 'head'},
#  {'id': 'd0_60',
#   'demographic_id': 'working_class',
#   'age': 62,
#   'education': 2,
#   'gender': 1,
#   'ethnicity': 0,
#   'family_ratio': 0.65,
#   'income': 22712,
#   'in_household': True,
#   'household_id': 'd0_hh75',
#   'relationship': 'partner'},
#  {'id': 'd0_267',
#   'demographic_id': 'rural_worker',
#   'age': 34,
#   'education': 2,
#   'gender': 1,
#   'ethnicity': 0,
#   'family_ratio': 0.7,
#   'income': 24654,
#   'in_household': True,
#   'household_id': 'd0_hh76',
#   'relationship': 'head'},
#  {'id': 'd0_455',
#   'demographic_id': 'farmer_agricultural',
#   'age': 56,
#   'education': 0,
#   'gender': 0,
#   'ethnicity': 0,
#   'family_ratio': 0.75,
#   'income': 47929,
#   'in_household': True,
#   'household_id': 'd0_hh76',
#   'relationship': 'partner'},
#  {'id': 'd0_165',
#   'demographic_id': 'middle_class',
#   'age': 54,
#   'education': 1,
#   'gender': 1,
#   'ethnicity': 0,
#   'family_ratio': 0.7,
#   'income': 33972,
#   'in_household': True,
#   'household_id': 'd0_hh77',
#   'relationship': 'head'},
#  {'id': 'd0_506',
#   'demographic_id': 'working_class',
#   'age': 44,
#   'education': 0,
#   'gender': 1,
#   'ethnicity': 0,
#   'family_ratio': 0.65,
#   'income': 15855,
#   'in_household': True,
#   'household_id': 'd0_hh78',
#   'relationship': 'head'},
#  {'id': 'd0_405',
#   'demographic_id': 'middle_class',
#   'age': 31,
#   'education': 1,
#   'gender': 1,
#   'ethnicity': 0,
#   'family_ratio': 0.7,
#   'income': 11002,
#   'in_household': True,
#   'household_id': 'd0_hh78',
#   'relationship': 'partner'},
#  {'id': 'd0_158',
#   'demographic_id': 'working_class',
#   'age': 54,
#   'education': 2,
#   'gender': 1,
#   'ethnicity': 0,
#   'family_ratio': 0.65,
#   'income': 34510,
#   'in_household': True,
#   'household_id': 'd0_hh79',
#   'relationship': 'head'},
#  {'id': 'd0_138',
#   'demographic_id': 'retired',
#   'age': 69,
#   'education': 3,
#   'gender': 0,
#   'ethnicity': 0,
#   'family_ratio': 0.3,
#   'income': 32892,
#   'in_household': True,
#   'household_id': 'd0_hh80',
#   'relationship': 'head'},
#  {'id': 'd0_467',
#   'demographic_id': 'farmer_agricultural',
#   'age': 48,
#   'education': 1,
#   'gender': 1,
#   'ethnicity': 0,
#   'family_ratio': 0.75,
#   'income': 20625,
#   'in_household': True,
#   'household_id': 'd0_hh80',
#   'relationship': 'partner'},
#  {'id': 'd0_239',
#   'demographic_id': 'farmer_agricultural',
#   'age': 60,
#   'education': 1,
#   'gender': 1,
#   'ethnicity': 0,
#   'family_ratio': 0.75,
#   'income': 12665,
#   'in_household': True,
#   'household_id': 'd0_hh81',
#   'relationship': 'head'},
#  {'id': 'd0_347',
#   'demographic_id': 'working_class',
#   'age': 58,
#   'education': 3,
#   'gender': 1,
#   'ethnicity': 0,
#   'family_ratio': 0.65,
#   'income': 26815,
#   'in_household': True,
#   'household_id': 'd0_hh81',
#   'relationship': 'partner'},
#  {'id': 'd0_445',
#   'demographic_id': 'rural_worker',
#   'age': 66,
#   'education': 2,
#   'gender': 0,
#   'ethnicity': 0,
#   'family_ratio': 0.7,
#   'income': 26605,
#   'in_household': True,
#   'household_id': 'd0_hh82',
#   'relationship': 'head'},
#  {'id': 'd0_29',
#   'demographic_id': 'working_class',
#   'age': 48,
#   'education': 3,
#   'gender': 0,
#   'ethnicity': 0,
#   'family_ratio': 0.65,
#   'income': 29572,
#   'in_household': True,
#   'household_id': 'd0_hh83',
#   'relationship': 'head'},
#  {'id': 'd0_172',
#   'demographic_id': 'rural_worker',
#   'age': 53,
#   'education': 1,
#   'gender': 1,
#   'ethnicity': 0,
#   'family_ratio': 0.7,
#   'income': 28284,
#   'in_household': True,
#   'household_id': 'd0_hh83',
#   'relationship': 'partner'},
#  {'id': 'd0_127',
#   'demographic_id': 'retired',
#   'age': 82,
#   'education': 0,
#   'gender': 1,
#   'ethnicity': 0,
#   'family_ratio': 0.3,
#   'income': 9483,
#   'in_household': True,
#   'household_id': 'd0_hh84',
#   'relationship': 'head'},
#  {'id': 'd0_218',
#   'demographic_id': 'rural_worker',
#   'age': 52,
#   'education': 2,
#   'gender': 1,
#   'ethnicity': 0,
#   'family_ratio': 0.7,
#   'income': 15916,
#   'in_household': True,
#   'household_id': 'd0_hh84',
#   'relationship': 'partner'},
#  {'id': 'd0_418',
#   'demographic_id': 'retired',
#   'age': 66,
#   'education': 1,
#   'gender': 0,
#   'ethnicity': 0,
#   'family_ratio': 0.3,
#   'income': 29744,
#   'in_household': True,
#   'household_id': 'd0_hh85',
#   'relationship': 'head'},
#  {'id': 'd0_103',
#   'demographic_id': 'working_class',
#   'age': 67,
#   'education': 3,
#   'gender': 1,
#   'ethnicity': 0,
#   'family_ratio': 0.65,
#   'income': 29512,
#   'in_household': True,
#   'household_id': 'd0_hh85',
#   'relationship': 'partner'},
#  {'id': 'd0_392',
#   'demographic_id': 'farmer_agricultural',
#   'age': 42,
#   'education': 2,
#   'gender': 1,
#   'ethnicity': 0,
#   'family_ratio': 0.75,
#   'income': 33493,
#   'in_household': True,
#   'household_id': 'd0_hh86',
#   'relationship': 'head'},
#  {'id': 'd0_461',
#   'demographic_id': 'farmer_agricultural',
#   'age': 50,
#   'education': 0,
#   'gender': 0,
#   'ethnicity': 0,
#   'family_ratio': 0.75,
#   'income': 29412,
#   'in_household': True,
#   'household_id': 'd0_hh86',
#   'relationship': 'partner'},
#  {'id': 'd0_115',
#   'demographic_id': 'farmer_agricultural',
#   'age': 27,
#   'education': 1,
#   'gender': 0,
#   'ethnicity': 0,
#   'family_ratio': 0.75,
#   'income': 36863,
#   'in_household': True,
#   'household_id': 'd0_hh87',
#   'relationship': 'head'},
#  {'id': 'd0_332',
#   'demographic_id': 'working_class',
#   'age': 56,
#   'education': 2,
#   'gender': 0,
#   'ethnicity': 0,
#   'family_ratio': 0.65,
#   'income': 27046,
#   'in_household': True,
#   'household_id': 'd0_hh87',
#   'relationship': 'partner'},
#  {'id': 'd0_200',
#   'demographic_id': 'farmer_agricultural',
#   'age': 58,
#   'education': 1,
#   'gender': 0,
#   'ethnicity': 0,
#   'family_ratio': 0.75,
#   'income': 47116,
#   'in_household': True,
#   'household_id': 'd0_hh88',
#   'relationship': 'head'},
#  {'id': 'd0_293',
#   'demographic_id': 'rural_worker',
#   'age': 45,
#   'education': 1,
#   'gender': 0,
#   'ethnicity': 0,
#   'family_ratio': 0.7,
#   'income': 28633,
#   'in_household': True,
#   'household_id': 'd0_hh88',
#   'relationship': 'partner'},
#  {'id': 'd0_376',
#   'demographic_id': 'working_class',
#   'age': 45,
#   'education': 0,
#   'gender': 0,
#   'ethnicity': 0,
#   'family_ratio': 0.65,
#   'income': 18846,
#   'in_household': True,
#   'household_id': 'd0_hh89',
#   'relationship': 'head'},
#  {'id': 'd0_185',
#   'demographic_id': 'rural_worker',
#   'age': 42,
#   'education': 1,
#   'gender': 0,
#   'ethnicity': 0,
#   'family_ratio': 0.7,
#   'income': 14774,
#   'in_household': True,
#   'household_id': 'd0_hh90',
#   'relationship': 'head'},
#  {'id': 'd0_67',
#   'demographic_id': 'rural_worker',
#   'age': 61,
#   'education': 1,
#   'gender': 1,
#   'ethnicity': 0,
#   'family_ratio': 0.7,
#   'income': 26507,
#   'in_household': True,
#   'household_id': 'd0_hh90',
#   'relationship': 'partner'},
#  {'id': 'd0_428',
#   'demographic_id': 'working_class',
#   'age': 48,
#   'education': 2,
#   'gender': 0,
#   'ethnicity': 0,
#   'family_ratio': 0.65,
#   'income': 15388,
#   'in_household': True,
#   'household_id': 'd0_hh91',
#   'relationship': 'head'},
#  {'id': 'd0_66',
#   'demographic_id': 'farmer_agricultural',
#   'age': 51,
#   'education': 1,
#   'gender': 1,
#   'ethnicity': 0,
#   'family_ratio': 0.75,
#   'income': 33063,
#   'in_household': True,
#   'household_id': 'd0_hh91',
#   'relationship': 'partner'},
#  {'id': 'd0_209',
#   'demographic_id': 'rural_worker',
#   'age': 60,
#   'education': 0,
#   'gender': 0,
#   'ethnicity': 0,
#   'family_ratio': 0.7,
#   'income': 5110,
#   'in_household': True,
#   'household_id': 'd0_hh92',
#   'relationship': 'head'},
#  {'id': 'd0_113',
#   'demographic_id': 'retired',
#   'age': 76,
#   'education': 0,
#   'gender': 1,
#   'ethnicity': 0,
#   'family_ratio': 0.3,
#   'income': 25043,
#   'in_household': True,
#   'household_id': 'd0_hh92',
#   'relationship': 'partner'},
#  {'id': 'd0_146',
#   'demographic_id': 'farmer_agricultural',
#   'age': 44,
#   'education': 2,
#   'gender': 1,
#   'ethnicity': 0,
#   'family_ratio': 0.75,
#   'income': 25161,
#   'in_household': True,
#   'household_id': 'd0_hh93',
#   'relationship': 'head'},
#  {'id': 'd0_164',
#   'demographic_id': 'working_class',
#   'age': 44,
#   'education': 3,
#   'gender': 0,
#   'ethnicity': 0,
#   'family_ratio': 0.65,
#   'income': 23530,
#   'in_household': True,
#   'household_id': 'd0_hh93',
#   'relationship': 'partner'},
#  {'id': 'd0_210',
#   'demographic_id': 'working_class',
#   'age': 65,
#   'education': 5,
#   'gender': 1,
#   'ethnicity': 0,
#   'family_ratio': 0.65,
#   'income': 22757,
#   'in_household': True,
#   'household_id': 'd0_hh94',
#   'relationship': 'head'},
#  {'id': 'd0_495',
#   'demographic_id': 'farmer_agricultural',
#   'age': 42,
#   'education': 2,
#   'gender': 0,
#   'ethnicity': 0,
#   'family_ratio': 0.75,
#   'income': 7404,
#   'in_household': True,
#   'household_id': 'd0_hh94',
#   'relationship': 'partner'},
#  {'id': 'd0_168',
#   'demographic_id': 'farmer_agricultural',
#   'age': 16,
#   'education': 1,
#   'gender': 1,
#   'ethnicity': 0,
#   'family_ratio': 0.75,
#   'income': 64306,
#   'in_household': True,
#   'household_id': 'd0_hh95',
#   'relationship': 'head'},
#  {'id': 'd0_38',
#   'demographic_id': 'middle_class',
#   'age': 45,
#   'education': 3,
#   'gender': 1,
#   'ethnicity': 0,
#   'family_ratio': 0.7,
#   'income': 40792,
#   'in_household': True,
#   'household_id': 'd0_hh96',
#   'relationship': 'head'},
#  {'id': 'd0_265',
#   'demographic_id': 'retired',
#   'age': 71,
#   'education': 4,
#   'gender': 1,
#   'ethnicity': 0,
#   'family_ratio': 0.3,
#   'income': 32592,
#   'in_household': True,
#   'household_id': 'd0_hh97',
#   'relationship': 'head'},
#  {'id': 'd0_410',
#   'demographic_id': 'farmer_agricultural',
#   'age': 45,
#   'education': 0,
#   'gender': 0,
#   'ethnicity': 0,
#   'family_ratio': 0.75,
#   'income': 10238,
#   'in_household': True,
#   'household_id': 'd0_hh97',
#   'relationship': 'partner'},
#  {'id': 'd0_276',
#   'demographic_id': 'farmer_agricultural',
#   'age': 66,
#   'education': 0,
#   'gender': 1,
#   'ethnicity': 0,
#   'family_ratio': 0.75,
#   'income': 33939,
#   'in_household': True,
#   'household_id': 'd0_hh98',
#   'relationship': 'head'},
#  {'id': 'd0_458',
#   'demographic_id': 'retired',
#   'age': 71,
#   'education': 3,
#   'gender': 0,
#   'ethnicity': 0,
#   'family_ratio': 0.3,
#   'income': 27560,
#   'in_household': True,
#   'household_id': 'd0_hh99',
#   'relationship': 'head'},
#  {'id': 'd0_123',
#   'demographic_id': 'rural_worker',
#   'age': 55,
#   'education': 1,
#   'gender': 1,
#   'ethnicity': 0,
#   'family_ratio': 0.7,
#   'income': 31302,
#   'in_household': True,
#   'household_id': 'd0_hh100',
#   'relationship': 'head'},
#  {'id': 'd0_299',
#   'demographic_id': 'working_class',
#   'age': 38,
#   'education': 3,
#   'gender': 1,
#   'ethnicity': 0,
#   'family_ratio': 0.65,
#   'income': 13714,
#   'in_household': True,
#   'household_id': 'd0_hh100',
#   'relationship': 'partner'},
#  {'id': 'd0_97',
#   'demographic_id': 'farmer_agricultural',
#   'age': 53,
#   'education': 3,
#   'gender': 0,
#   'ethnicity': 0,
#   'family_ratio': 0.75,
#   'income': -10499,
#   'in_household': True,
#   'household_id': 'd0_hh101',
#   'relationship': 'head'},
#  {'id': 'd0_477',
#   'demographic_id': 'retired',
#   'age': 64,
#   'education': 1,
#   'gender': 1,
#   'ethnicity': 0,
#   'family_ratio': 0.3,
#   'income': 5645,
#   'in_household': True,
#   'household_id': 'd0_hh101',
#   'relationship': 'partner'},
#  {'id': 'd0_12',
#   'demographic_id': 'retired',
#   'age': 71,
#   'education': 1,
#   'gender': 1,
#   'ethnicity': 0,
#   'family_ratio': 0.3,
#   'income': 13755,
#   'in_household': True,
#   'household_id': 'd0_hh101',
#   'relationship': 'partner'},
#  {'id': 'd0_174',
#   'demographic_id': 'retired',
#   'age': 82,
#   'education': 2,
#   'gender': 0,
#   'ethnicity': 0,
#   'family_ratio': 0.3,
#   'income': 36038,
#   'in_household': True,
#   'household_id': 'd0_hh101',
#   'relationship': 'partner'},
#  {'id': 'd0_453',
#   'demographic_id': 'middle_class',
#   'age': 42,
#   'education': 3,
#   'gender': 0,
#   'ethnicity': 0,
#   'family_ratio': 0.7,
#   'income': 48995,
#   'in_household': True,
#   'household_id': 'd0_hh102',
#   'relationship': 'head'},
#  {'id': 'd0_308',
#   'demographic_id': 'retired',
#   'age': 70,
#   'education': 5,
#   'gender': 0,
#   'ethnicity': 0,
#   'family_ratio': 0.3,
#   'income': 20302,
#   'in_household': True,
#   'household_id': 'd0_hh102',
#   'relationship': 'partner'},
#  {'id': 'd0_107',
#   'demographic_id': 'farmer_agricultural',
#   'age': 49,
#   'education': 3,
#   'gender': 1,
#   'ethnicity': 0,
#   'family_ratio': 0.75,
#   'income': 39263,
#   'in_household': True,
#   'household_id': 'd0_hh103',
#   'relationship': 'head'},
#  {'id': 'd0_325',
#   'demographic_id': 'retired',
#   'age': 63,
#   'education': 4,
#   'gender': 0,
#   'ethnicity': 0,
#   'family_ratio': 0.3,
#   'income': 17876,
#   'in_household': True,
#   'household_id': 'd0_hh103',
#   'relationship': 'partner'},
#  {'id': 'd0_219',
#   'demographic_id': 'middle_class',
#   'age': 46,
#   'education': 6,
#   'gender': 0,
#   'ethnicity': 0,
#   'family_ratio': 0.7,
#   'income': 34114,
#   'in_household': True,
#   'household_id': 'd0_hh104',
#   'relationship': 'head'},
#  {'id': 'd0_263',
#   'demographic_id': 'retired',
#   'age': 70,
#   'education': 1,
#   'gender': 1,
#   'ethnicity': 0,
#   'family_ratio': 0.3,
#   'income': 9496,
#   'in_household': True,
#   'household_id': 'd0_hh104',
#   'relationship': 'partner'},
#  {'id': 'd0_19',
#   'demographic_id': 'farmer_agricultural',
#   'age': 69,
#   'education': 1,
#   'gender': 0,
#   'ethnicity': 0,
#   'family_ratio': 0.75,
#   'income': 42524,
#   'in_household': True,
#   'household_id': 'd0_hh105',
#   'relationship': 'head'},
#  {'id': 'd0_431',
#   'demographic_id': 'farmer_agricultural',
#   'age': 26,
#   'education': 2,
#   'gender': 0,
#   'ethnicity': 0,
#   'family_ratio': 0.75,
#   'income': 40682,
#   'in_household': True,
#   'household_id': 'd0_hh105',
#   'relationship': 'partner'},
#  {'id': 'd0_492',
#   'demographic_id': 'retired',
#   'age': 88,
#   'education': 0,
#   'gender': 1,
#   'ethnicity': 0,
#   'family_ratio': 0.3,
#   'income': 18093,
#   'in_household': True,
#   'household_id': 'd0_hh105',
#   'relationship': 'partner'},
#  {'id': 'd0_363',
#   'demographic_id': 'middle_class',
#   'age': 42,
#   'education': 3,
#   'gender': 0,
#   'ethnicity': 0,
#   'family_ratio': 0.7,
#   'income': 38102,
#   'in_household': True,
#   'household_id': 'd0_hh106',
#   'relationship': 'head'},
#  {'id': 'd0_438',
#   'demographic_id': 'affluent_professional',
#   'age': 47,
#   'education': 8,
#   'gender': 1,
#   'ethnicity': 0,
#   'family_ratio': 0.6,
#   'income': 60941,
#   'in_household': True,
#   'household_id': 'd0_hh106',
#   'relationship': 'partner'},
#  {'id': 'd0_421',
#   'demographic_id': 'working_class',
#   'age': 43,
#   'education': 2,
#   'gender': 1,
#   'ethnicity': 0,
#   'family_ratio': 0.65,
#   'income': 25076,
#   'in_household': True,
#   'household_id': 'd0_hh107',
#   'relationship': 'head'},
#  {'id': 'd0_111',
#   'demographic_id': 'working_class',
#   'age': 36,
#   'education': 2,
#   'gender': 0,
#   'ethnicity': 0,
#   'family_ratio': 0.65,
#   'income': 16267,
#   'in_household': True,
#   'household_id': 'd0_hh107',
#   'relationship': 'partner'},
#  {'id': 'd0_449',
#   'demographic_id': 'retired',
#   'age': 66,
#   'education': 4,
#   'gender': 0,
#   'ethnicity': 0,
#   'family_ratio': 0.3,
#   'income': 20908,
#   'in_household': True,
#   'household_id': 'd0_hh108',
#   'relationship': 'head'},
#  {'id': 'd0_173',
#   'demographic_id': 'retired',
#   'age': 85,
#   'education': 1,
#   'gender': 1,
#   'ethnicity': 0,
#   'family_ratio': 0.3,
# ...
#   'education': 5,
#   'gender': 0,
#   'ethnicity': 0,
#   'family_ratio': 0.7,
#   'income': 35647,
#   'in_household': True,
#   'household_id': 'd1_hh228',
#   'relationship': 'partner'},
#  {'id': 'd1_291',
#   'demographic_id': 'affluent_professional',
#   'age': 48,
#   'education': 7,
#   'gender': 0,
#   'ethnicity': 0,
#   'family_ratio': 0.6,
#   'income': 54298,
#   'in_household': True,
#   'household_id': 'd1_hh229',
#   'relationship': 'head'},
#  {'id': 'd1_349',
#   'demographic_id': 'affluent_professional',
#   'age': 55,
#   'education': 6,
#   'gender': 1,
#   'ethnicity': 0,
#   'family_ratio': 0.6,
#   'income': 53959,
#   'in_household': True,
#   'household_id': 'd1_hh229',
#   'relationship': 'partner'},
#  {'id': 'd1_224',
#   'demographic_id': 'working_class',
#   'age': 39,
#   'education': 2,
#   'gender': 0,
#   'ethnicity': 0,
#   'family_ratio': 0.65,
#   'income': 35325,
#   'in_household': True,
#   'household_id': 'd1_hh230',
#   'relationship': 'head'},
#  {'id': 'd1_11',
#   'demographic_id': 'working_class',
#   'age': 45,
#   'education': 2,
#   'gender': 1,
#   'ethnicity': 0,
#   'family_ratio': 0.65,
#   'income': 28305,
#   'in_household': True,
#   'household_id': 'd1_hh231',
#   'relationship': 'head'},
#  {'id': 'd1_306',
#   'demographic_id': 'middle_class',
#   'age': 37,
#   'education': 6,
#   'gender': 1,
#   'ethnicity': 0,
#   'family_ratio': 0.7,
#   'income': 64527,
#   'in_household': True,
#   'household_id': 'd1_hh232',
#   'relationship': 'head'},
#  {'id': 'd1_152',
#   'demographic_id': 'middle_class',
#   'age': 40,
#   'education': 5,
#   'gender': 0,
#   'ethnicity': 0,
#   'family_ratio': 0.7,
#   'income': 33237,
#   'in_household': True,
#   'household_id': 'd1_hh232',
#   'relationship': 'partner'},
#  {'id': 'd1_238',
#   'demographic_id': 'working_class',
#   'age': 30,
#   'education': 3,
#   'gender': 1,
#   'ethnicity': 0,
#   'family_ratio': 0.65,
#   'income': 35131,
#   'in_household': True,
#   'household_id': 'd1_hh233',
#   'relationship': 'head'},
#  {'id': 'd1_181',
#   'demographic_id': 'low_income',
#   'age': 40,
#   'education': 1,
#   'gender': 0,
#   'ethnicity': 0,
#   'family_ratio': 0.5,
#   'income': 19330,
#   'in_household': True,
#   'household_id': 'd1_hh233',
#   'relationship': 'partner'},
#  {'id': 'd1_178',
#   'demographic_id': 'young_professional',
#   'age': 28,
#   'education': 6,
#   'gender': 0,
#   'ethnicity': 0,
#   'family_ratio': 0.2,
#   'income': 36963,
#   'in_household': True,
#   'household_id': 'd1_hh234',
#   'relationship': 'head'},
#  {'id': 'd1_131',
#   'demographic_id': 'low_income',
#   'age': 32,
#   'education': 1,
#   'gender': 1,
#   'ethnicity': 0,
#   'family_ratio': 0.5,
#   'income': 14584,
#   'in_household': True,
#   'household_id': 'd1_hh235',
#   'relationship': 'head'},
#  {'id': 'd1_419',
#   'demographic_id': 'working_class',
#   'age': 58,
#   'education': 1,
#   'gender': 1,
#   'ethnicity': 0,
#   'family_ratio': 0.65,
#   'income': 29946,
#   'in_household': True,
#   'household_id': 'd1_hh236',
#   'relationship': 'head'},
#  {'id': 'd1_117',
#   'demographic_id': 'low_income',
#   'age': 31,
#   'education': 0,
#   'gender': 0,
#   'ethnicity': 0,
#   'family_ratio': 0.5,
#   'income': 21197,
#   'in_household': True,
#   'household_id': 'd1_hh236',
#   'relationship': 'partner'},
#  {'id': 'd1_302',
#   'demographic_id': 'working_class',
#   'age': 38,
#   'education': 2,
#   'gender': 1,
#   'ethnicity': 0,
#   'family_ratio': 0.65,
#   'income': 25713,
#   'in_household': True,
#   'household_id': 'd1_hh237',
#   'relationship': 'head'},
#  {'id': 'd1_239',
#   'demographic_id': 'young_professional',
#   'age': 32,
#   'education': 5,
#   'gender': 1,
#   'ethnicity': 0,
#   'family_ratio': 0.2,
#   'income': 43649,
#   'in_household': True,
#   'household_id': 'd1_hh237',
#   'relationship': 'partner'},
#  {'id': 'd1_52',
#   'demographic_id': 'middle_class',
#   'age': 44,
#   'education': 4,
#   'gender': 1,
#   'ethnicity': 0,
#   'family_ratio': 0.7,
#   'income': 20696,
#   'in_household': True,
#   'household_id': 'd1_hh238',
#   'relationship': 'head'},
#  {'id': 'd1_253',
#   'demographic_id': 'affluent_professional',
#   'age': 37,
#   'education': 6,
#   'gender': 0,
#   'ethnicity': 0,
#   'family_ratio': 0.6,
#   'income': 120348,
#   'in_household': True,
#   'household_id': 'd1_hh239',
#   'relationship': 'head'},
#  {'id': 'd1_139',
#   'demographic_id': 'young_professional',
#   'age': 28,
#   'education': 6,
#   'gender': 0,
#   'ethnicity': 0,
#   'family_ratio': 0.2,
#   'income': 32878,
#   'in_household': True,
#   'household_id': 'd1_hh239',
#   'relationship': 'partner'},
#  {'id': 'd1_249',
#   'demographic_id': 'retired',
#   'age': 81,
#   'education': 2,
#   'gender': 0,
#   'ethnicity': 0,
#   'family_ratio': 0.3,
#   'income': -1833,
#   'in_household': True,
#   'household_id': 'd1_hh240',
#   'relationship': 'head'},
#  {'id': 'd1_385',
#   'demographic_id': 'young_professional',
#   'age': 23,
#   'education': 4,
#   'gender': 1,
#   'ethnicity': 0,
#   'family_ratio': 0.2,
#   'income': 49274,
#   'in_household': True,
#   'household_id': 'd1_hh240',
#   'relationship': 'partner'},
#  {'id': 'd1_83',
#   'demographic_id': 'middle_class',
#   'age': 36,
#   'education': 5,
#   'gender': 0,
#   'ethnicity': 0,
#   'family_ratio': 0.7,
#   'income': 48326,
#   'in_household': True,
#   'household_id': 'd1_hh241',
#   'relationship': 'head'},
#  {'id': 'd1_205',
#   'demographic_id': 'affluent_professional',
#   'age': 48,
#   'education': 5,
#   'gender': 1,
#   'ethnicity': 0,
#   'family_ratio': 0.6,
#   'income': 45017,
#   'in_household': True,
#   'household_id': 'd1_hh242',
#   'relationship': 'head'},
#  {'id': 'd1_267',
#   'demographic_id': 'middle_class',
#   'age': 50,
#   'education': 3,
#   'gender': 0,
#   'ethnicity': 0,
#   'family_ratio': 0.7,
#   'income': 38511,
#   'in_household': True,
#   'household_id': 'd1_hh242',
#   'relationship': 'partner'},
#  {'id': 'd1_432',
#   'demographic_id': 'middle_class',
#   'age': 38,
#   'education': 2,
#   'gender': 0,
#   'ethnicity': 0,
#   'family_ratio': 0.7,
#   'income': 15259,
#   'in_household': True,
#   'household_id': 'd1_hh243',
#   'relationship': 'head'},
#  {'id': 'd1_219',
#   'demographic_id': 'student',
#   'age': 16,
#   'education': 7,
#   'gender': 1,
#   'ethnicity': 0,
#   'family_ratio': 0.05,
#   'income': 4612,
#   'in_household': True,
#   'household_id': 'd1_hh243',
#   'relationship': 'partner'},
#  {'id': 'd1_229',
#   'demographic_id': 'middle_class',
#   'age': 46,
#   'education': 4,
#   'gender': 1,
#   'ethnicity': 0,
#   'family_ratio': 0.7,
#   'income': 43731,
#   'in_household': True,
#   'household_id': 'd1_hh244',
#   'relationship': 'head'},
#  {'id': 'd1_276',
#   'demographic_id': 'middle_class',
#   'age': 38,
#   'education': 3,
#   'gender': 1,
#   'ethnicity': 0,
#   'family_ratio': 0.7,
#   'income': 18230,
#   'in_household': True,
#   'household_id': 'd1_hh244',
#   'relationship': 'partner'},
#  {'id': 'd1_74',
#   'demographic_id': 'working_class',
#   'age': 46,
#   'education': 1,
#   'gender': 1,
#   'ethnicity': 0,
#   'family_ratio': 0.65,
#   'income': 22455,
#   'in_household': True,
#   'household_id': 'd1_hh245',
#   'relationship': 'head'},
#  {'id': 'd1_427',
#   'demographic_id': 'low_income',
#   'age': 37,
#   'education': 1,
#   'gender': 0,
#   'ethnicity': 0,
#   'family_ratio': 0.5,
#   'income': 13962,
#   'in_household': True,
#   'household_id': 'd1_hh245',
#   'relationship': 'partner'},
#  {'id': 'd1_250',
#   'demographic_id': 'middle_class',
#   'age': 50,
#   'education': 1,
#   'gender': 0,
#   'ethnicity': 0,
#   'family_ratio': 0.7,
#   'income': 55639,
#   'in_household': True,
#   'household_id': 'd1_hh246',
#   'relationship': 'head'},
#  {'id': 'd1_295',
#   'demographic_id': 'working_class',
#   'age': 34,
#   'education': 0,
#   'gender': 1,
#   'ethnicity': 0,
#   'family_ratio': 0.65,
#   'income': 24763,
#   'in_household': True,
#   'household_id': 'd1_hh247',
#   'relationship': 'head'},
#  {'id': 'd1_228',
#   'demographic_id': 'retired',
#   'age': 76,
#   'education': 0,
#   'gender': 1,
#   'ethnicity': 0,
#   'family_ratio': 0.3,
#   'income': 14152,
#   'in_household': True,
#   'household_id': 'd1_hh247',
#   'relationship': 'partner'},
#  {'id': 'd1_197',
#   'demographic_id': 'low_income',
#   'age': 71,
#   'education': 0,
#   'gender': 1,
#   'ethnicity': 0,
#   'family_ratio': 0.5,
#   'income': 11569,
#   'in_household': True,
#   'household_id': 'd1_hh248',
#   'relationship': 'head'},
#  {'id': 'd1_329',
#   'demographic_id': 'middle_class',
#   'age': 58,
#   'education': 7,
#   'gender': 0,
#   'ethnicity': 0,
#   'family_ratio': 0.7,
#   'income': 51602,
#   'in_household': True,
#   'household_id': 'd1_hh248',
#   'relationship': 'partner'},
#  {'id': 'd1_341',
#   'demographic_id': 'middle_class',
#   'age': 25,
#   'education': 6,
#   'gender': 0,
#   'ethnicity': 0,
#   'family_ratio': 0.7,
#   'income': 31474,
#   'in_household': True,
#   'household_id': 'd1_hh249',
#   'relationship': 'head'},
#  {'id': 'd1_294',
#   'demographic_id': 'working_class',
#   'age': 41,
#   'education': 0,
#   'gender': 0,
#   'ethnicity': 0,
#   'family_ratio': 0.65,
#   'income': 10667,
#   'in_household': True,
#   'household_id': 'd1_hh249',
#   'relationship': 'partner'},
#  {'id': 'd1_411',
#   'demographic_id': 'affluent_professional',
#   'age': 44,
#   'education': 4,
#   'gender': 1,
#   'ethnicity': 0,
#   'family_ratio': 0.6,
#   'income': 52313,
#   'in_household': True,
#   'household_id': 'd1_hh250',
#   'relationship': 'head'},
#  {'id': 'd1_16',
#   'demographic_id': 'low_income',
#   'age': 52,
#   'education': 1,
#   'gender': 1,
#   'ethnicity': 0,
#   'family_ratio': 0.5,
#   'income': 22792,
#   'in_household': True,
#   'household_id': 'd1_hh251',
#   'relationship': 'head'},
#  {'id': 'd1_350',
#   'demographic_id': 'working_class',
#   'age': 46,
#   'education': 4,
#   'gender': 1,
#   'ethnicity': 0,
#   'family_ratio': 0.65,
#   'income': 37729,
#   'in_household': True,
#   'household_id': 'd1_hh252',
#   'relationship': 'head'},
#  {'id': 'd1_36',
#   'demographic_id': 'student',
#   'age': 26,
#   'education': 4,
#   'gender': 0,
#   'ethnicity': 0,
#   'family_ratio': 0.05,
#   'income': 17121,
#   'in_household': True,
#   'household_id': 'd1_hh252',
#   'relationship': 'partner'},
#  {'id': 'd1_158',
#   'demographic_id': 'affluent_professional',
#   'age': 31,
#   'education': 7,
#   'gender': 1,
#   'ethnicity': 0,
#   'family_ratio': 0.6,
#   'income': 40505,
#   'in_household': True,
#   'household_id': 'd1_hh253',
#   'relationship': 'head'},
#  {'id': 'd1_288',
#   'demographic_id': 'middle_class',
#   'age': 43,
#   'education': 4,
#   'gender': 1,
#   'ethnicity': 0,
#   'family_ratio': 0.7,
#   'income': 44854,
#   'in_household': True,
#   'household_id': 'd1_hh253',
#   'relationship': 'partner'},
#  {'id': 'd1_415',
#   'demographic_id': 'working_class',
#   'age': 31,
#   'education': 2,
#   'gender': 1,
#   'ethnicity': 0,
#   'family_ratio': 0.65,
#   'income': 31407,
#   'in_household': True,
#   'household_id': 'd1_hh254',
#   'relationship': 'head'},
#  {'id': 'd1_111',
#   'demographic_id': 'student',
#   'age': 20,
#   'education': 6,
#   'gender': 0,
#   'ethnicity': 0,
#   'family_ratio': 0.05,
#   'income': 5756,
#   'in_household': True,
#   'household_id': 'd1_hh255',
#   'relationship': 'head'},
#  {'id': 'd1_55',
#   'demographic_id': 'affluent_professional',
#   'age': 38,
#   'education': 8,
#   'gender': 0,
#   'ethnicity': 0,
#   'family_ratio': 0.6,
#   'income': 75131,
#   'in_household': True,
#   'household_id': 'd1_hh256',
#   'relationship': 'head'},
#  {'id': 'd1_356',
#   'demographic_id': 'working_class',
#   'age': 37,
#   'education': 4,
#   'gender': 0,
#   'ethnicity': 0,
#   'family_ratio': 0.65,
#   'income': 24748,
#   'in_household': True,
#   'household_id': 'd1_hh256',
#   'relationship': 'partner'},
#  {'id': 'd1_392',
#   'demographic_id': 'middle_class',
#   'age': 41,
#   'education': 2,
#   'gender': 0,
#   'ethnicity': 0,
#   'family_ratio': 0.7,
#   'income': 39366,
#   'in_household': True,
#   'household_id': 'd1_hh257',
#   'relationship': 'head'},
#  {'id': 'd1_103',
#   'demographic_id': 'low_income',
#   'age': 13,
#   'education': 1,
#   'gender': 0,
#   'ethnicity': 0,
#   'family_ratio': 0.5,
#   'income': 9618,
#   'in_household': True,
#   'household_id': 'd1_hh257',
#   'relationship': 'partner'},
#  {'id': 'd1_0',
#   'demographic_id': 'student',
#   'age': 16,
#   'education': 5,
#   'gender': 0,
#   'ethnicity': 0,
#   'family_ratio': 0.05,
#   'income': 20230,
#   'in_household': True,
#   'household_id': 'd1_hh258',
#   'relationship': 'head'},
#  {'id': 'd1_15',
#   'demographic_id': 'young_professional',
#   'age': 30,
#   'education': 6,
#   'gender': 0,
#   'ethnicity': 0,
#   'family_ratio': 0.2,
#   'income': 39618,
#   'in_household': True,
#   'household_id': 'd1_hh258',
#   'relationship': 'partner'},
#  {'id': 'd1_439',
#   'demographic_id': 'young_professional',
#   'age': 27,
#   'education': 5,
#   'gender': 0,
#   'ethnicity': 0,
#   'family_ratio': 0.2,
#   'income': 25377,
#   'in_household': True,
#   'household_id': 'd1_hh258',
#   'relationship': 'partner'},
#  {'id': 'd1_81',
#   'demographic_id': 'young_professional',
#   'age': 29,
#   'education': 5,
#   'gender': 0,
#   'ethnicity': 0,
#   'family_ratio': 0.2,
#   'income': 10923,
#   'in_household': True,
#   'household_id': 'd1_hh258',
#   'relationship': 'partner'},
#  {'id': 'd1_130',
#   'demographic_id': 'low_income',
#   'age': 43,
#   'education': 1,
#   'gender': 0,
#   'ethnicity': 0,
#   'family_ratio': 0.5,
#   'income': 15468,
#   'in_household': True,
#   'household_id': 'd1_hh259',
#   'relationship': 'head'},
#  {'id': 'd1_275',
#   'demographic_id': 'retired',
#   'age': 68,
#   'education': 4,
#   'gender': 0,
#   'ethnicity': 0,
#   'family_ratio': 0.3,
#   'income': 24811,
#   'in_household': True,
#   'household_id': 'd1_hh260',
#   'relationship': 'head'},
#  {'id': 'd1_409',
#   'demographic_id': 'student',
#   'age': 25,
#   'education': 4,
#   'gender': 1,
#   'ethnicity': 0,
#   'family_ratio': 0.05,
#   'income': 5155,
#   'in_household': True,
#   'household_id': 'd1_hh260',
#   'relationship': 'partner'},
#  {'id': 'd1_417',
#   'demographic_id': 'affluent_professional',
#   'age': 58,
#   'education': 8,
#   'gender': 0,
#   'ethnicity': 0,
#   'family_ratio': 0.6,
#   'income': 31712,
#   'in_household': True,
#   'household_id': 'd1_hh261',
#   'relationship': 'head'},
#  {'id': 'd1_373',
#   'demographic_id': 'affluent_professional',
#   'age': 54,
#   'education': 7,
#   'gender': 0,
#   'ethnicity': 0,
#   'family_ratio': 0.6,
#   'income': 74905,
#   'in_household': True,
#   'household_id': 'd1_hh261',
#   'relationship': 'partner'},
#  {'id': 'd1_159',
#   'demographic_id': 'middle_class',
#   'age': 56,
#   'education': 8,
#   'gender': 1,
#   'ethnicity': 0,
#   'family_ratio': 0.7,
#   'income': 42397,
#   'in_household': True,
#   'household_id': 'd1_hh262',
#   'relationship': 'head'},
#  {'id': 'd1_21',
#   'demographic_id': 'working_class',
#   'age': 48,
#   'education': 2,
#   'gender': 0,
#   'ethnicity': 0,
#   'family_ratio': 0.65,
#   'income': 14231,
#   'in_household': True,
#   'household_id': 'd1_hh263',
#   'relationship': 'head'},
#  {'id': 'd1_327',
#   'demographic_id': 'low_income',
#   'age': 12,
#   'education': 2,
#   'gender': 1,
#   'ethnicity': 0,
#   'family_ratio': 0.5,
#   'income': 24610,
#   'in_household': True,
#   'household_id': 'd1_hh263',
#   'relationship': 'partner'},
#  {'id': 'd1_101',
#   'demographic_id': 'low_income',
#   'age': 55,
#   'education': 0,
#   'gender': 1,
#   'ethnicity': 0,
#   'family_ratio': 0.5,
#   'income': 20349,
#   'in_household': True,
#   'household_id': 'd1_hh264',
#   'relationship': 'head'},
#  {'id': 'd1_133',
#   'demographic_id': 'middle_class',
#   'age': 31,
#   'education': 5,
#   'gender': 1,
#   'ethnicity': 0,
#   'family_ratio': 0.7,
#   'income': 15281,
#   'in_household': True,
#   'household_id': 'd1_hh265',
#   'relationship': 'head'},
#  {'id': 'd1_10',
#   'demographic_id': 'retired',
#   'age': 82,
#   'education': 3,
#   'gender': 0,
#   'ethnicity': 0,
#   'family_ratio': 0.3,
#   'income': 23952,
#   'in_household': True,
#   'household_id': 'd1_hh265',
#   'relationship': 'partner'},
#  {'id': 'd2_241',
#   'demographic_id': 'working_class',
#   'age': 39,
#   'education': 1,
#   'gender': 1,
#   'ethnicity': 0,
#   'family_ratio': 0.65,
#   'income': 32153,
#   'in_household': True,
#   'household_id': 'd2_hh0',
#   'relationship': 'head'},
#  {'id': 'd2_204',
#   'demographic_id': 'middle_class',
#   'age': 59,
#   'education': 4,
#   'gender': 1,
#   'ethnicity': 0,
#   'family_ratio': 0.7,
#   'income': 47673,
#   'in_household': True,
#   'household_id': 'd2_hh1',
#   'relationship': 'head'},
#  {'id': 'd2_125',
#   'demographic_id': 'working_class',
#   'age': 48,
#   'education': 2,
#   'gender': 1,
#   'ethnicity': 0,
#   'family_ratio': 0.65,
#   'income': 28424,
#   'in_household': True,
#   'household_id': 'd2_hh1',
#   'relationship': 'partner'},
#  ...]
